# %% [markdown]
# Given a paper, say in our example the BERT paper that was published last year:
# https://www.semanticscholar.org/paper/BERT%3A-Pre-training-of-Deep-Bidirectional-for-Devlin-Chang/df2b0e26d0599ce3e70df8a9da02e51594e0e992
#
# Our goal is to obtain a summary of what other papers talk about this paper.
#
# In order to achieve that, we would like to obtain:
# 1. A list of all the papers that cites this paper (600+ of them in the case of BERT)
# 2. A PDF version for each of these papers
# 3. In each of these referencing PDF's, the precise location at which the BERT paper is cited
#
# To obtain 1, we use Semantic Scholar API:  http://api.semanticscholar.org/v1/paper/df2b0e26d0599ce3e70df8a9da02e51594e0e992 ( in the "citations" field).
#
# To obtain 2, we can download them directly from arxiv: https://arxiv.org/pdf/[arxiv ID].pdf, for example: https://arxiv.org/pdf/1907.04829.pdf
#
# To obtain 3, I recommend this application: https://github.com/kermitt2/grobid . You can try out the demo here by uploading a PDF: http://cloud.science-miner.com/grobid/

# %%
import numpy as np
import pandas as pd
import requests
import json


# We can set api endpoints in either of following methods to get url   
#url = "http://api.semanticscholar.org/v1/paper/arXiv:1810.04805"
#url = " http://api.semanticscholar.org/v1/paper/df2b0e26d0599ce3e70df8a9da02e51594e0e992"
url = "http://api.semanticscholar.org/v1/paper/arXiv:1802.05365"
JSONContent = requests.get(url).json()

#using .dumps() function that takes an object and creates string of it.
content = json.dumps(JSONContent, indent = 4, sort_keys=True)

print(content)
# Out:
# {
#     "abstract": "We introduce a new type of deep contextualized word representation that models both (1) complex characteristics of word use (e.g., syntax and semantics), and (2) how these uses vary across linguistic contexts (i.e., to model polysemy). Our word vectors are learned functions of the internal states of a deep bidirectional language model (biLM), which is pretrained on a large text corpus. We show that these representations can be easily added to existing models and significantly improve the state of the art across six challenging NLP problems, including question answering, textual entailment and sentiment analysis. We also present an analysis showing that exposing the deep internals of the pretrained network is crucial, allowing downstream models to mix different types of semi-supervision signals.",
#     "arxivId": "1802.05365",
#     "authors": [
#         {
#             "authorId": "39139825",
#             "name": "Matthew E. Peters",
#             "url": "https://www.semanticscholar.org/author/39139825"
#         },
#         {
#             "authorId": "50043859",
#             "name": "Mark Neumann",
#             "url": "https://www.semanticscholar.org/author/50043859"
#         },
#         {
#             "authorId": "2136562",
#             "name": "Mohit Iyyer",
#             "url": "https://www.semanticscholar.org/author/2136562"
#         },
#         {
#             "authorId": "40642935",
#             "name": "Matt Gardner",
#             "url": "https://www.semanticscholar.org/author/40642935"
#         },
#         {
#             "authorId": "143997772",
#             "name": "Christopher Clark",
#             "url": "https://www.semanticscholar.org/author/143997772"
#         },
#         {
#             "authorId": "2544107",
#             "name": "Kenton Lee",
#             "url": "https://www.semanticscholar.org/author/2544107"
#         },
#         {
#             "authorId": "1982950",
#             "name": "Luke S. Zettlemoyer",
#             "url": "https://www.semanticscholar.org/author/1982950"
#         }
#     ],
#     "citationVelocity": 385,
#     "citations": [
#         {
#             "arxivId": "1905.05538",
#             "authors": [
#                 {
#                     "authorId": "145562616",
#                     "name": "Maria Becker",
#                     "url": "https://www.semanticscholar.org/author/145562616"
#                 },
#                 {
#                     "authorId": "17352821",
#                     "name": "Michael Staniek",
#                     "url": "https://www.semanticscholar.org/author/17352821"
#                 },
#                 {
#                     "authorId": "2256003",
#                     "name": "Vivi Nastase",
#                     "url": "https://www.semanticscholar.org/author/2256003"
#                 },
#                 {
#                     "authorId": "143876555",
#                     "name": "Anette Frank",
#                     "url": "https://www.semanticscholar.org/author/143876555"
#                 }
#             ],
#             "doi": null,
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "fea13dcb73f9754ca498ef700769ec21793e6870",
#             "title": "Assessing the Difficulty of Classifying ConceptNet Relations in a Multi-Label Classification Setting",
#             "url": "https://www.semanticscholar.org/paper/fea13dcb73f9754ca498ef700769ec21793e6870",
#             "venue": "ArXiv",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "36212180",
#                     "name": "Sawan Kumar",
#                     "url": "https://www.semanticscholar.org/author/36212180"
#                 },
#                 {
#                     "authorId": "2604064",
#                     "name": "Sharmistha Jat",
#                     "url": "https://www.semanticscholar.org/author/2604064"
#                 },
#                 {
#                     "authorId": "9393246",
#                     "name": "Karan Saxena",
#                     "url": "https://www.semanticscholar.org/author/9393246"
#                 },
#                 {
#                     "authorId": "2408872",
#                     "name": "Partha Pratim Talukdar",
#                     "url": "https://www.semanticscholar.org/author/2408872"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "425e249c1c91128c016d27ce353540aed19eea7e",
#             "title": "Zero-shot Word Sense Disambiguation using Sense Definition Embeddings",
#             "url": "https://www.semanticscholar.org/paper/425e249c1c91128c016d27ce353540aed19eea7e",
#             "venue": "ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": "1808.06305",
#             "authors": [
#                 {
#                     "authorId": null,
#                     "name": "Fenxiao Chen",
#                     "url": null
#                 },
#                 {
#                     "authorId": null,
#                     "name": "Angela Wang",
#                     "url": null
#                 },
#                 {
#                     "authorId": null,
#                     "name": "C.-C. Jay Kuo",
#                     "url": null
#                 }
#             ],
#             "doi": "10.1109/ICME.2019.00129",
#             "intent": [
#                 "background",
#                 "result"
#             ],
#             "isInfluential": false,
#             "paperId": "fca28d8de84cae5bc8f48cb8cfc5cedf106f62a1",
#             "title": "Post-Processing of Word Representations via Variance Normalization and Dynamic Embedding",
#             "url": "https://www.semanticscholar.org/paper/fca28d8de84cae5bc8f48cb8cfc5cedf106f62a1",
#             "venue": "2019 IEEE International Conference on Multimedia and Expo (ICME)",
#             "year": 2018
#         },
#         {
#             "arxivId": "1904.12683",
#             "authors": [
#                 {
#                     "authorId": "97393346",
#                     "name": "Sebastian Hofst\u00e4tter",
#                     "url": "https://www.semanticscholar.org/author/97393346"
#                 },
#                 {
#                     "authorId": "2844293",
#                     "name": "Navid Rekabsaz",
#                     "url": "https://www.semanticscholar.org/author/2844293"
#                 },
#                 {
#                     "authorId": "1764160",
#                     "name": "Carsten Eickhoff",
#                     "url": "https://www.semanticscholar.org/author/1764160"
#                 },
#                 {
#                     "authorId": "1699657",
#                     "name": "Allan Hanbury",
#                     "url": "https://www.semanticscholar.org/author/1699657"
#                 }
#             ],
#             "doi": "10.1145/3331184.3331344",
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "68acfb44aed9a138b0693facadda025d90693f61",
#             "title": "On the Effect of Low-Frequency Terms on Neural-IR Models",
#             "url": "https://www.semanticscholar.org/paper/68acfb44aed9a138b0693facadda025d90693f61",
#             "venue": "SIGIR",
#             "year": 2019
#         },
#         {
#             "arxivId": "1908.03548",
#             "authors": [
#                 {
#                     "authorId": "1701747",
#                     "name": "Zongcheng Ji",
#                     "url": "https://www.semanticscholar.org/author/1701747"
#                 },
#                 {
#                     "authorId": "144492566",
#                     "name": "Qiang Wei",
#                     "url": "https://www.semanticscholar.org/author/144492566"
#                 },
#                 {
#                     "authorId": "46485463",
#                     "name": "Hua Xu",
#                     "url": "https://www.semanticscholar.org/author/46485463"
#                 }
#             ],
#             "doi": null,
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "8492269d2bb474d57d6def97efcf86c42735554a",
#             "title": "BERT-based Ranking for Biomedical Entity Normalization",
#             "url": "https://www.semanticscholar.org/paper/8492269d2bb474d57d6def97efcf86c42735554a",
#             "venue": "ArXiv",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "3041223",
#                     "name": "Alessandro Magnani",
#                     "url": "https://www.semanticscholar.org/author/3041223"
#                 },
#                 {
#                     "authorId": "144774112",
#                     "name": "Feng Liu",
#                     "url": "https://www.semanticscholar.org/author/144774112"
#                 },
#                 {
#                     "authorId": "144917411",
#                     "name": "Min Xie",
#                     "url": "https://www.semanticscholar.org/author/144917411"
#                 },
#                 {
#                     "authorId": "2226316",
#                     "name": "Somnath Banerjee",
#                     "url": "https://www.semanticscholar.org/author/2226316"
#                 }
#             ],
#             "doi": "10.1145/3308560.3316603",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "bd40bc8f5b32f3b72495c5fdd83719796a212cd1",
#             "title": "Neural Product Retrieval at Walmart.com",
#             "url": "https://www.semanticscholar.org/paper/bd40bc8f5b32f3b72495c5fdd83719796a212cd1",
#             "venue": "WWW",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "2884976",
#                     "name": "Jingbo Shang",
#                     "url": "https://www.semanticscholar.org/author/2884976"
#                 },
#                 {
#                     "authorId": "3363642",
#                     "name": "Jiaming Shen",
#                     "url": "https://www.semanticscholar.org/author/3363642"
#                 },
#                 {
#                     "authorId": "3355833",
#                     "name": "Liyuan Liu",
#                     "url": "https://www.semanticscholar.org/author/3355833"
#                 },
#                 {
#                     "authorId": "145325584",
#                     "name": "Jiawei Han",
#                     "url": "https://www.semanticscholar.org/author/145325584"
#                 }
#             ],
#             "doi": "10.1145/3292500.3332275",
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "39c4e6082cca859d9277af126b6c7d3418da27c1",
#             "title": "Constructing and Mining Heterogeneous Information Networks from Massive Text",
#             "url": "https://www.semanticscholar.org/paper/39c4e6082cca859d9277af126b6c7d3418da27c1",
#             "venue": "KDD",
#             "year": 2019
#         },
#         {
#             "arxivId": "1906.07854",
#             "authors": [
#                 {
#                     "authorId": "2303577",
#                     "name": "Jiin Nam",
#                     "url": "https://www.semanticscholar.org/author/2303577"
#                 },
#                 {
#                     "authorId": "144517919",
#                     "name": "Seunghyun Yoon",
#                     "url": "https://www.semanticscholar.org/author/144517919"
#                 },
#                 {
#                     "authorId": "1731707",
#                     "name": "Kyomin Jung",
#                     "url": "https://www.semanticscholar.org/author/1731707"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "7db308823bdd2b297da2c56096c5dd57b65c6152",
#             "title": "Surf at MEDIQA 2019: Improving Performance of Natural Language Inference in the Clinical Domain by Adopting Pre-trained Language Model",
#             "url": "https://www.semanticscholar.org/paper/7db308823bdd2b297da2c56096c5dd57b65c6152",
#             "venue": "BioNLP@ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "25135288",
#                     "name": "Maryam Honari Jahromi",
#                     "url": "https://www.semanticscholar.org/author/25135288"
#                 }
#             ],
#             "doi": null,
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "69ab4622c2cad8a6e03c5061cb1a563e57ff0e31",
#             "title": "Decoding semantic representations during production of minimal adjective-noun phrases",
#             "url": "https://www.semanticscholar.org/paper/69ab4622c2cad8a6e03c5061cb1a563e57ff0e31",
#             "venue": "",
#             "year": 2019
#         },
#         {
#             "arxivId": "1904.00585",
#             "authors": [
#                 {
#                     "authorId": "144105651",
#                     "name": "Xiang Dai",
#                     "url": "https://www.semanticscholar.org/author/144105651"
#                 },
#                 {
#                     "authorId": "1785901",
#                     "name": "Sarvnaz Karimi",
#                     "url": "https://www.semanticscholar.org/author/1785901"
#                 },
#                 {
#                     "authorId": "2753838",
#                     "name": "Ben Hachey",
#                     "url": "https://www.semanticscholar.org/author/2753838"
#                 },
#                 {
#                     "authorId": "145212976",
#                     "name": "C\u00e9cile Paris",
#                     "url": "https://www.semanticscholar.org/author/145212976"
#                 }
#             ],
#             "doi": "10.18653/v1/n19-1149",
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "61d24c45e41f4f6cfc3d9da2f03efde1862b839e",
#             "title": "Using Similarity Measures to Select Pretraining Data for NER",
#             "url": "https://www.semanticscholar.org/paper/61d24c45e41f4f6cfc3d9da2f03efde1862b839e",
#             "venue": "NAACL-HLT",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "144906624",
#                     "name": "Alex Wang",
#                     "url": "https://www.semanticscholar.org/author/144906624"
#                 },
#                 {
#                     "authorId": "47655060",
#                     "name": "Jan Hula",
#                     "url": "https://www.semanticscholar.org/author/47655060"
#                 },
#                 {
#                     "authorId": "2465658",
#                     "name": "Patrick Xia",
#                     "url": "https://www.semanticscholar.org/author/2465658"
#                 },
#                 {
#                     "authorId": "18081502",
#                     "name": "Raghavendra Pappagari",
#                     "url": "https://www.semanticscholar.org/author/18081502"
#                 },
#                 {
#                     "authorId": "145534175",
#                     "name": "R. Thomas McCoy",
#                     "url": "https://www.semanticscholar.org/author/145534175"
#                 },
#                 {
#                     "authorId": "48322149",
#                     "name": "Roma Patel",
#                     "url": "https://www.semanticscholar.org/author/48322149"
#                 },
#                 {
#                     "authorId": "8756748",
#                     "name": "Najoung Kim",
#                     "url": "https://www.semanticscholar.org/author/8756748"
#                 },
#                 {
#                     "authorId": "6117577",
#                     "name": "Ian Tenney",
#                     "url": "https://www.semanticscholar.org/author/6117577"
#                 },
#                 {
#                     "authorId": "46843847",
#                     "name": "Yinghui Huang",
#                     "url": "https://www.semanticscholar.org/author/46843847"
#                 },
#                 {
#                     "authorId": "65794308",
#                     "name": "Katherin Yu",
#                     "url": "https://www.semanticscholar.org/author/65794308"
#                 },
#                 {
#                     "authorId": "46193777",
#                     "name": "Shuning Jin",
#                     "url": "https://www.semanticscholar.org/author/46193777"
#                 },
#                 {
#                     "authorId": "1751964",
#                     "name": "Berlin Chen",
#                     "url": "https://www.semanticscholar.org/author/1751964"
#                 },
#                 {
#                     "authorId": "7536576",
#                     "name": "Benjamin Van Durme",
#                     "url": "https://www.semanticscholar.org/author/7536576"
#                 },
#                 {
#                     "authorId": "3024698",
#                     "name": "Edouard Grave",
#                     "url": "https://www.semanticscholar.org/author/3024698"
#                 },
#                 {
#                     "authorId": "2949185",
#                     "name": "Ellie Pavlick",
#                     "url": "https://www.semanticscholar.org/author/2949185"
#                 },
#                 {
#                     "authorId": "3644767",
#                     "name": "Samuel R. Bowman",
#                     "url": "https://www.semanticscholar.org/author/3644767"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "6b170d8b06f5272422807e0afa159699cf4a2bdd",
#             "title": "Intermediate Task Model Intermediate Task Output BERT Input Text Intermediate Task Model Intermediate Task Output ELMo BiLSTM Input Text Target Task Model Target Task Output Intermediate Task-Trained BERT Input Text Pretraining Task Model Pretraining Task Output BiLSTM",
#             "url": "https://www.semanticscholar.org/paper/6b170d8b06f5272422807e0afa159699cf4a2bdd",
#             "venue": "",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "34574116",
#                     "name": "Marija Stanojevic",
#                     "url": "https://www.semanticscholar.org/author/34574116"
#                 },
#                 {
#                     "authorId": "151041487",
#                     "name": "Jumanah Alshehri",
#                     "url": "https://www.semanticscholar.org/author/151041487"
#                 },
#                 {
#                     "authorId": "1825318",
#                     "name": "Eduard Constantin Dragut",
#                     "url": "https://www.semanticscholar.org/author/1825318"
#                 },
#                 {
#                     "authorId": "3844766",
#                     "name": "Zoran Obradovic",
#                     "url": "https://www.semanticscholar.org/author/3844766"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "ee6c929b5829c735170e3ef07038f60a9de12d1d",
#             "title": "Biased News Data Influence on Classifying Social Media Posts",
#             "url": "https://www.semanticscholar.org/paper/ee6c929b5829c735170e3ef07038f60a9de12d1d",
#             "venue": "NewsIR@SIGIR",
#             "year": 2019
#         },
#         {
#             "arxivId": "1901.11504",
#             "authors": [
#                 {
#                     "authorId": "46522098",
#                     "name": "Xiaodong Liu",
#                     "url": "https://www.semanticscholar.org/author/46522098"
#                 },
#                 {
#                     "authorId": "50462546",
#                     "name": "Pengcheng He",
#                     "url": "https://www.semanticscholar.org/author/50462546"
#                 },
#                 {
#                     "authorId": "7307263",
#                     "name": "Weizhu Chen",
#                     "url": "https://www.semanticscholar.org/author/7307263"
#                 },
#                 {
#                     "authorId": "1800422",
#                     "name": "Jianfeng Gao",
#                     "url": "https://www.semanticscholar.org/author/1800422"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "658721bc13b0fa97366d38c05a96bf0a9f4bb0ac",
#             "title": "Multi-Task Deep Neural Networks for Natural Language Understanding",
#             "url": "https://www.semanticscholar.org/paper/658721bc13b0fa97366d38c05a96bf0a9f4bb0ac",
#             "venue": "ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [],
#             "doi": null,
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "fca6b04c126f1279fe8a83c4126c99f1370b20a6",
#             "title": "Pretraining for Conditional Generation with Pseudo Self Attention",
#             "url": "https://www.semanticscholar.org/paper/fca6b04c126f1279fe8a83c4126c99f1370b20a6",
#             "venue": "",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "7247665",
#                     "name": "Ruijun Liu",
#                     "url": "https://www.semanticscholar.org/author/7247665"
#                 },
#                 {
#                     "authorId": "150351659",
#                     "name": "Yuqian Shi",
#                     "url": "https://www.semanticscholar.org/author/150351659"
#                 },
#                 {
#                     "authorId": "150058464",
#                     "name": "Changjiang Ji",
#                     "url": "https://www.semanticscholar.org/author/150058464"
#                 },
#                 {
#                     "authorId": "81036476",
#                     "name": "Ming Qing Jia",
#                     "url": "https://www.semanticscholar.org/author/81036476"
#                 }
#             ],
#             "doi": "10.1109/ACCESS.2019.2925059",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "7b38c23d267649ca13df99bd3dbf846e1a95fd0d",
#             "title": "A Survey of Sentiment Analysis Based on Transfer Learning",
#             "url": "https://www.semanticscholar.org/paper/7b38c23d267649ca13df99bd3dbf846e1a95fd0d",
#             "venue": "IEEE Access",
#             "year": 2019
#         },
#         {
#             "arxivId": "1810.05201",
#             "authors": [
#                 {
#                     "authorId": "20825661",
#                     "name": "Kellie Webster",
#                     "url": "https://www.semanticscholar.org/author/20825661"
#                 },
#                 {
#                     "authorId": "144409897",
#                     "name": "Marta Recasens",
#                     "url": "https://www.semanticscholar.org/author/144409897"
#                 },
#                 {
#                     "authorId": "82840075",
#                     "name": "Vera Axelrod",
#                     "url": "https://www.semanticscholar.org/author/82840075"
#                 },
#                 {
#                     "authorId": "1759379",
#                     "name": "Jason Baldridge",
#                     "url": "https://www.semanticscholar.org/author/1759379"
#                 }
#             ],
#             "doi": "10.1162/tacl_a_00240",
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "57032c1e327c88a53ab41c17e91bf1406f9ef5c9",
#             "title": "Mind the GAP: A Balanced Corpus of Gendered Ambiguous Pronouns",
#             "url": "https://www.semanticscholar.org/paper/57032c1e327c88a53ab41c17e91bf1406f9ef5c9",
#             "venue": "Transactions of the Association for Computational Linguistics",
#             "year": 2018
#         },
#         {
#             "arxivId": "1906.05149",
#             "authors": [
#                 {
#                     "authorId": "46731063",
#                     "name": "Laura Aina",
#                     "url": "https://www.semanticscholar.org/author/46731063"
#                 },
#                 {
#                     "authorId": "2807281",
#                     "name": "Kristina Gulordava",
#                     "url": "https://www.semanticscholar.org/author/2807281"
#                 },
#                 {
#                     "authorId": "1807810",
#                     "name": "Gemma Boleda",
#                     "url": "https://www.semanticscholar.org/author/1807810"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "2785d56159d01ad050b8014410d370e8270f9c1b",
#             "title": "Putting Words in Context: LSTM Language Models and Lexical Ambiguity",
#             "url": "https://www.semanticscholar.org/paper/2785d56159d01ad050b8014410d370e8270f9c1b",
#             "venue": "ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": "1905.10892",
#             "authors": [
#                 {
#                     "authorId": "10783142",
#                     "name": "Ilias Chalkidis",
#                     "url": "https://www.semanticscholar.org/author/10783142"
#                 },
#                 {
#                     "authorId": "121316873",
#                     "name": "Manos Fergadiotis",
#                     "url": "https://www.semanticscholar.org/author/121316873"
#                 },
#                 {
#                     "authorId": "1950133",
#                     "name": "Prodromos Malakasiotis",
#                     "url": "https://www.semanticscholar.org/author/1950133"
#                 },
#                 {
#                     "authorId": "3238627",
#                     "name": "Nikolaos Aletras",
#                     "url": "https://www.semanticscholar.org/author/3238627"
#                 },
#                 {
#                     "authorId": "1752430",
#                     "name": "Ion Androutsopoulos",
#                     "url": "https://www.semanticscholar.org/author/1752430"
#                 }
#             ],
#             "doi": "10.18653/v1/w19-2209",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "f3a78149013e4610fdd98f1913500cf1d4b61e7c",
#             "title": "Extreme Multi-Label Legal Text Classification: A case study in EU Legislation",
#             "url": "https://www.semanticscholar.org/paper/f3a78149013e4610fdd98f1913500cf1d4b61e7c",
#             "venue": "ArXiv",
#             "year": 2019
#         },
#         {
#             "arxivId": "1811.08705",
#             "authors": [
#                 {
#                     "authorId": "137873505",
#                     "name": "Joewie J. Koh",
#                     "url": "https://www.semanticscholar.org/author/137873505"
#                 },
#                 {
#                     "authorId": "137076822",
#                     "name": "Barton Rhodes",
#                     "url": "https://www.semanticscholar.org/author/137076822"
#                 }
#             ],
#             "doi": "10.1109/BigData.2018.8622066",
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "18e073e4bcc2a95d82ac824ff8a7c5595403d8e4",
#             "title": "Inline Detection of Domain Generation Algorithms with Context-Sensitive Word Embeddings",
#             "url": "https://www.semanticscholar.org/paper/18e073e4bcc2a95d82ac824ff8a7c5595403d8e4",
#             "venue": "2018 IEEE International Conference on Big Data (Big Data)",
#             "year": 2018
#         },
#         {
#             "arxivId": "1902.10985",
#             "authors": [
#                 {
#                     "authorId": "3259155",
#                     "name": "David Vilares",
#                     "url": "https://www.semanticscholar.org/author/3259155"
#                 },
#                 {
#                     "authorId": "30671790",
#                     "name": "Mostafa Abdou",
#                     "url": "https://www.semanticscholar.org/author/30671790"
#                 },
#                 {
#                     "authorId": "1700187",
#                     "name": "Anders S\u00f8gaard",
#                     "url": "https://www.semanticscholar.org/author/1700187"
#                 }
#             ],
#             "doi": "10.18653/v1/n19-1341",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "e814ee99e2fd7872cb5b93dadef15cd3d209fe08",
#             "title": "Better, Faster, Stronger Sequence Tagging Constituent Parsers",
#             "url": "https://www.semanticscholar.org/paper/e814ee99e2fd7872cb5b93dadef15cd3d209fe08",
#             "venue": "NAACL-HLT",
#             "year": 2019
#         },
#         {
#             "arxivId": "1808.09147",
#             "authors": [
#                 {
#                     "authorId": "1705260",
#                     "name": "Yizhong Wang",
#                     "url": "https://www.semanticscholar.org/author/1705260"
#                 },
#                 {
#                     "authorId": "1695451",
#                     "name": "Sujian Li",
#                     "url": "https://www.semanticscholar.org/author/1695451"
#                 },
#                 {
#                     "authorId": "7788583",
#                     "name": "Jingfeng Yang",
#                     "url": "https://www.semanticscholar.org/author/7788583"
#                 }
#             ],
#             "doi": "10.18653/v1/d18-1116",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "4d7d955826d1f75269f2dec84d7a714ad83c6009",
#             "title": "Toward Fast and Accurate Neural Discourse Segmentation",
#             "url": "https://www.semanticscholar.org/paper/4d7d955826d1f75269f2dec84d7a714ad83c6009",
#             "venue": "EMNLP",
#             "year": 2018
#         },
#         {
#             "arxivId": "1907.12108",
#             "authors": [
#                 {
#                     "authorId": "3710218",
#                     "name": "Zhaojiang Lin",
#                     "url": "https://www.semanticscholar.org/author/3710218"
#                 },
#                 {
#                     "authorId": "145011005",
#                     "name": "Peng Xu",
#                     "url": "https://www.semanticscholar.org/author/145011005"
#                 },
#                 {
#                     "authorId": "9162688",
#                     "name": "Genta Indra Winata",
#                     "url": "https://www.semanticscholar.org/author/9162688"
#                 },
#                 {
#                     "authorId": "46271391",
#                     "name": "Zihan Liu",
#                     "url": "https://www.semanticscholar.org/author/46271391"
#                 },
#                 {
#                     "authorId": "40539650",
#                     "name": "Pascale Fung",
#                     "url": "https://www.semanticscholar.org/author/40539650"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "9fc0ddd6811cf682500d12585da78385b01a1e6b",
#             "title": "CAiRE: An End-to-End Empathetic Chatbot",
#             "url": "https://www.semanticscholar.org/paper/9fc0ddd6811cf682500d12585da78385b01a1e6b",
#             "venue": "ArXiv",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "50017297",
#                     "name": "Xiao long Han",
#                     "url": "https://www.semanticscholar.org/author/50017297"
#                 },
#                 {
#                     "authorId": "39669401",
#                     "name": "Qi Wang",
#                     "url": "https://www.semanticscholar.org/author/39669401"
#                 }
#             ],
#             "doi": "10.1109/ITNEC.2019.8729174",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "770c0e3a1f63aad0a40b40eefcb8bd8eed50689e",
#             "title": "Evaluating Word Embeddings based on Hypernymy Relations",
#             "url": "https://www.semanticscholar.org/paper/770c0e3a1f63aad0a40b40eefcb8bd8eed50689e",
#             "venue": "2019 IEEE 3rd Information Technology, Networking, Electronic and Automation Control Conference (ITNEC)",
#             "year": 2019
#         },
#         {
#             "arxivId": "1905.11833",
#             "authors": [
#                 {
#                     "authorId": "2822168",
#                     "name": "Mariya Toneva",
#                     "url": "https://www.semanticscholar.org/author/2822168"
#                 },
#                 {
#                     "authorId": "2001748",
#                     "name": "Leila Wehbe",
#                     "url": "https://www.semanticscholar.org/author/2001748"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "result"
#             ],
#             "isInfluential": false,
#             "paperId": "e3567830f32444917af2d06c213435b7f1a92cd2",
#             "title": "Interpreting and improving natural-language processing (in machines) with natural language-processing (in the brain)",
#             "url": "https://www.semanticscholar.org/paper/e3567830f32444917af2d06c213435b7f1a92cd2",
#             "venue": "ArXiv",
#             "year": 2019
#         },
#         {
#             "arxivId": "1905.00078",
#             "authors": [
#                 {
#                     "authorId": "123625463",
#                     "name": "Hendrik Purwins",
#                     "url": "https://www.semanticscholar.org/author/123625463"
#                 },
#                 {
#                     "authorId": "13397099",
#                     "name": "Bo Li",
#                     "url": "https://www.semanticscholar.org/author/13397099"
#                 },
#                 {
#                     "authorId": "1684454",
#                     "name": "Tuomas Virtanen",
#                     "url": "https://www.semanticscholar.org/author/1684454"
#                 },
#                 {
#                     "authorId": "122882120",
#                     "name": "Jan Schl&#x00FC;ter",
#                     "url": "https://www.semanticscholar.org/author/122882120"
#                 },
#                 {
#                     "authorId": "40604450",
#                     "name": "Shuo-Yiin Chang",
#                     "url": "https://www.semanticscholar.org/author/40604450"
#                 },
#                 {
#                     "authorId": "98801017",
#                     "name": "Tara Sainath",
#                     "url": "https://www.semanticscholar.org/author/98801017"
#                 }
#             ],
#             "doi": "10.1109/JSTSP.2019.2908700",
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "8e15ce5a1d38d3d17287e9e191a5f47a50ec4771",
#             "title": "Deep Learning for Audio Signal Processing",
#             "url": "https://www.semanticscholar.org/paper/8e15ce5a1d38d3d17287e9e191a5f47a50ec4771",
#             "venue": "IEEE Journal of Selected Topics in Signal Processing",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "8801869",
#                     "name": "Chongyang Tao",
#                     "url": "https://www.semanticscholar.org/author/8801869"
#                 },
#                 {
#                     "authorId": "145717888",
#                     "name": "Wei Wu",
#                     "url": "https://www.semanticscholar.org/author/145717888"
#                 },
#                 {
#                     "authorId": "46747953",
#                     "name": "Can Xu",
#                     "url": "https://www.semanticscholar.org/author/46747953"
#                 },
#                 {
#                     "authorId": "1717629",
#                     "name": "Yansong Feng",
#                     "url": "https://www.semanticscholar.org/author/1717629"
#                 },
#                 {
#                     "authorId": "144060462",
#                     "name": "Dongyan Zhao",
#                     "url": "https://www.semanticscholar.org/author/144060462"
#                 },
#                 {
#                     "authorId": "144539156",
#                     "name": "Rui Yan",
#                     "url": "https://www.semanticscholar.org/author/144539156"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "2c063484f426383a0f8056268ad8fd431b3af77d",
#             "title": "Improving Matching Models with Contextualized Word Representations for Multi-turn Response Selection in Retrieval-based Chatbots",
#             "url": "https://www.semanticscholar.org/paper/2c063484f426383a0f8056268ad8fd431b3af77d",
#             "venue": "ArXiv",
#             "year": 2018
#         },
#         {
#             "arxivId": "1811.08610",
#             "authors": [
#                 {
#                     "authorId": "46842323",
#                     "name": "Zhipeng Chen",
#                     "url": "https://www.semanticscholar.org/author/46842323"
#                 },
#                 {
#                     "authorId": "3043830",
#                     "name": "Yiming Cui",
#                     "url": "https://www.semanticscholar.org/author/3043830"
#                 },
#                 {
#                     "authorId": "145910725",
#                     "name": "Wentao Ma",
#                     "url": "https://www.semanticscholar.org/author/145910725"
#                 },
#                 {
#                     "authorId": "1754280",
#                     "name": "Shijin Wang",
#                     "url": "https://www.semanticscholar.org/author/1754280"
#                 },
#                 {
#                     "authorId": "40936264",
#                     "name": "Guoping Hu",
#                     "url": "https://www.semanticscholar.org/author/40936264"
#                 }
#             ],
#             "doi": "10.1609/aaai.v33i01.33016276",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "5d469c463c6f8aae46dcaf71b6254079566757b7",
#             "title": "Convolutional Spatial Attention Model for Reading Comprehension with Multiple-Choice Questions",
#             "url": "https://www.semanticscholar.org/paper/5d469c463c6f8aae46dcaf71b6254079566757b7",
#             "venue": "AAAI",
#             "year": 2018
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "144447820",
#                     "name": "Yi Tay",
#                     "url": "https://www.semanticscholar.org/author/144447820"
#                 },
#                 {
#                     "authorId": "1755919",
#                     "name": "Anh Tuan Luu",
#                     "url": "https://www.semanticscholar.org/author/1755919"
#                 },
#                 {
#                     "authorId": "144194328",
#                     "name": "Siu Cheung Hui",
#                     "url": "https://www.semanticscholar.org/author/144194328"
#                 }
#             ],
#             "doi": "10.18653/v1/d18-1238",
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "c3a2623cebd9ad68f0c383805c1862a4c5139093",
#             "title": "Multi-Granular Sequence Encoding via Dilated Compositional Units for Reading Comprehension",
#             "url": "https://www.semanticscholar.org/paper/c3a2623cebd9ad68f0c383805c1862a4c5139093",
#             "venue": "EMNLP",
#             "year": 2018
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "2111626",
#                     "name": "Tongtao Zhang",
#                     "url": "https://www.semanticscholar.org/author/2111626"
#                 },
#                 {
#                     "authorId": "144016781",
#                     "name": "Heng Ji",
#                     "url": "https://www.semanticscholar.org/author/144016781"
#                 },
#                 {
#                     "authorId": "2707234",
#                     "name": "Avirup Sil",
#                     "url": "https://www.semanticscholar.org/author/2707234"
#                 }
#             ],
#             "doi": "10.1162/dint_a_00014",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "ea00a63c2acd145839eb6f6bbc01a5cfb4930d43",
#             "title": "Joint Entity and Event Extraction with Generative Adversarial Imitation Learning",
#             "url": "https://www.semanticscholar.org/paper/ea00a63c2acd145839eb6f6bbc01a5cfb4930d43",
#             "venue": "Data Intelligence",
#             "year": 2019
#         },
#         {
#             "arxivId": "1905.07129",
#             "authors": [
#                 {
#                     "authorId": "2621696",
#                     "name": "Zhengyan Zhang",
#                     "url": "https://www.semanticscholar.org/author/2621696"
#                 },
#                 {
#                     "authorId": "145760444",
#                     "name": "Xu Han",
#                     "url": "https://www.semanticscholar.org/author/145760444"
#                 },
#                 {
#                     "authorId": "49293248",
#                     "name": "Zhiyuan Liu",
#                     "url": "https://www.semanticscholar.org/author/49293248"
#                 },
#                 {
#                     "authorId": "145820291",
#                     "name": "Xin Jiang",
#                     "url": "https://www.semanticscholar.org/author/145820291"
#                 },
#                 {
#                     "authorId": "1753344",
#                     "name": "Maosong Sun",
#                     "url": "https://www.semanticscholar.org/author/1753344"
#                 },
#                 {
#                     "authorId": "47362346",
#                     "name": "Qun Liu",
#                     "url": "https://www.semanticscholar.org/author/47362346"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "5f994dc8cae24ca9d1ed629e517fcc652660ddde",
#             "title": "ERNIE: Enhanced Language Representation with Informative Entities",
#             "url": "https://www.semanticscholar.org/paper/5f994dc8cae24ca9d1ed629e517fcc652660ddde",
#             "venue": "ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": null,
#                     "name": "Alan Ansell",
#                     "url": null
#                 },
#                 {
#                     "authorId": null,
#                     "name": "Felipe Bravo-Marquez",
#                     "url": null
#                 },
#                 {
#                     "authorId": null,
#                     "name": "Bernhard Pfahringer",
#                     "url": null
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "470d52bf5108ee23395e4bdc3b3273f582cf5ab8",
#             "title": "An ELMo-inspired approach to SemDeep-5's Word-in-Context task",
#             "url": "https://www.semanticscholar.org/paper/470d52bf5108ee23395e4bdc3b3273f582cf5ab8",
#             "venue": "SemDeep@IJCAI",
#             "year": 2019
#         },
#         {
#             "arxivId": "1906.05468",
#             "authors": [
#                 {
#                     "authorId": "145714972",
#                     "name": "Aditya Joshi",
#                     "url": "https://www.semanticscholar.org/author/145714972"
#                 },
#                 {
#                     "authorId": "1785901",
#                     "name": "Sarvnaz Karimi",
#                     "url": "https://www.semanticscholar.org/author/1785901"
#                 },
#                 {
#                     "authorId": "40619352",
#                     "name": "Ross Sparks",
#                     "url": "https://www.semanticscholar.org/author/40619352"
#                 },
#                 {
#                     "authorId": "145212976",
#                     "name": "C\u00e9cile Paris",
#                     "url": "https://www.semanticscholar.org/author/145212976"
#                 },
#                 {
#                     "authorId": "46741763",
#                     "name": "C. Raina MacIntyre",
#                     "url": "https://www.semanticscholar.org/author/46741763"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "8ffc75d9f2e1e3c2f77f37822b89cf3a5fcd5ff2",
#             "title": "A Comparison of Word-based and Context-based Representations for Classification Problems in Health Informatics",
#             "url": "https://www.semanticscholar.org/paper/8ffc75d9f2e1e3c2f77f37822b89cf3a5fcd5ff2",
#             "venue": "BioNLP@ACL",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "139097094",
#                     "name": "Vincent Segonne",
#                     "url": "https://www.semanticscholar.org/author/139097094"
#                 },
#                 {
#                     "authorId": "2636107",
#                     "name": "Marie Candito",
#                     "url": "https://www.semanticscholar.org/author/2636107"
#                 },
#                 {
#                     "authorId": "2704047",
#                     "name": "Beno\u00eet Crabb\u00e9",
#                     "url": "https://www.semanticscholar.org/author/2704047"
#                 }
#             ],
#             "doi": null,
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "bc9915dc85e386b51e1490758ffcfc629b8527be",
#             "title": "Using Wiktionary as a resource for WSD : the case of French verbs",
#             "url": "https://www.semanticscholar.org/paper/bc9915dc85e386b51e1490758ffcfc629b8527be",
#             "venue": "IWCS",
#             "year": 2019
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "150120568",
#                     "name": "Hicham El Boukkouri",
#                     "url": "https://www.semanticscholar.org/author/150120568"
#                 },
#                 {
#                     "authorId": "1679133",
#                     "name": "Olivier Ferret",
#                     "url": "https://www.semanticscholar.org/author/1679133"
#                 },
#                 {
#                     "authorId": "48365459",
#                     "name": "Thomas Lavergne",
# ...
#             "year": 2011
#         },
#         {
#             "arxivId": "1606.05250",
#             "authors": [
#                 {
#                     "authorId": "2706258",
#                     "name": "Pranav Rajpurkar",
#                     "url": "https://www.semanticscholar.org/author/2706258"
#                 },
#                 {
#                     "authorId": "1679327",
#                     "name": "Jian Zhang",
#                     "url": "https://www.semanticscholar.org/author/1679327"
#                 },
#                 {
#                     "authorId": "2787620",
#                     "name": "Konstantin Lopyrev",
#                     "url": "https://www.semanticscholar.org/author/2787620"
#                 },
#                 {
#                     "authorId": "145419642",
#                     "name": "Percy Liang",
#                     "url": "https://www.semanticscholar.org/author/145419642"
#                 }
#             ],
#             "doi": "10.18653/v1/d16-1264",
#             "intent": [
#                 "background"
#             ],
#             "isInfluential": false,
#             "paperId": "05dd7254b632376973f3a1b4d39485da17814df5",
#             "title": "SQuAD: 100, 000+ Questions for Machine Comprehension of Text",
#             "url": "https://www.semanticscholar.org/paper/05dd7254b632376973f3a1b4d39485da17814df5",
#             "venue": "EMNLP",
#             "year": 2016
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "1734174",
#                     "name": "Mitchell P. Marcus",
#                     "url": "https://www.semanticscholar.org/author/1734174"
#                 },
#                 {
#                     "authorId": "2424234",
#                     "name": "Beatrice Santorini",
#                     "url": "https://www.semanticscholar.org/author/2424234"
#                 },
#                 {
#                     "authorId": "2063206",
#                     "name": "Mary Ann Marcinkiewicz",
#                     "url": "https://www.semanticscholar.org/author/2063206"
#                 }
#             ],
#             "doi": "10.21236/ada273556",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "0b44fcbeea9415d400c5f5789d6b892b6f98daff",
#             "title": "Building a Large Annotated Corpus of English: The Penn Treebank",
#             "url": "https://www.semanticscholar.org/paper/0b44fcbeea9415d400c5f5789d6b892b6f98daff",
#             "venue": "Computational Linguistics",
#             "year": 1993
#         },
#         {
#             "arxivId": "1603.01354",
#             "authors": [
#                 {
#                     "authorId": "2378954",
#                     "name": "Xuezhe Ma",
#                     "url": "https://www.semanticscholar.org/author/2378954"
#                 },
#                 {
#                     "authorId": "144547315",
#                     "name": "Eduard H. Hovy",
#                     "url": "https://www.semanticscholar.org/author/144547315"
#                 }
#             ],
#             "doi": "10.18653/v1/p16-1101",
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "8dd6aae51e31a72752c4be5cddbdd76dfdc6cda4",
#             "title": "End-to-end Sequence Labeling via Bi-directional LSTM-CNNs-CRF",
#             "url": "https://www.semanticscholar.org/paper/8dd6aae51e31a72752c4be5cddbdd76dfdc6cda4",
#             "venue": "ACL",
#             "year": 2016
#         },
#         {
#             "arxivId": "1611.01603",
#             "authors": [
#                 {
#                     "authorId": "4418074",
#                     "name": "Min Joon Seo",
#                     "url": "https://www.semanticscholar.org/author/4418074"
#                 },
#                 {
#                     "authorId": "2684226",
#                     "name": "Aniruddha Kembhavi",
#                     "url": "https://www.semanticscholar.org/author/2684226"
#                 },
#                 {
#                     "authorId": "143787583",
#                     "name": "Ali Farhadi",
#                     "url": "https://www.semanticscholar.org/author/143787583"
#                 },
#                 {
#                     "authorId": "2548384",
#                     "name": "Hannaneh Hajishirzi",
#                     "url": "https://www.semanticscholar.org/author/2548384"
#                 }
#             ],
#             "doi": null,
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "007ab5528b3bd310a80d553cccad4b78dc496b02",
#             "title": "Bidirectional Attention Flow for Machine Comprehension",
#             "url": "https://www.semanticscholar.org/paper/007ab5528b3bd310a80d553cccad4b78dc496b02",
#             "venue": "ICLR",
#             "year": 2016
#         },
#         {
#             "arxivId": "1607.04492",
#             "authors": [
#                 {
#                     "authorId": "2227827",
#                     "name": "Tsendsuren Munkhdalai",
#                     "url": "https://www.semanticscholar.org/author/2227827"
#                 },
#                 {
#                     "authorId": "1792198",
#                     "name": "Hongtao Yu",
#                     "url": "https://www.semanticscholar.org/author/1792198"
#                 }
#             ],
#             "doi": "10.18653/v1/e17-1002",
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "705dcc8eadba137834e4b0359e2d696d4b209f5b",
#             "title": "Neural Tree Indexers for Text Understanding",
#             "url": "https://www.semanticscholar.org/paper/705dcc8eadba137834e4b0359e2d696d4b209f5b",
#             "venue": "EACL",
#             "year": 2016
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "143845796",
#                     "name": "Jeffrey Pennington",
#                     "url": "https://www.semanticscholar.org/author/143845796"
#                 },
#                 {
#                     "authorId": "2166511",
#                     "name": "Richard Socher",
#                     "url": "https://www.semanticscholar.org/author/2166511"
#                 },
#                 {
#                     "authorId": "144783904",
#                     "name": "Christopher D. Manning",
#                     "url": "https://www.semanticscholar.org/author/144783904"
#                 }
#             ],
#             "doi": "10.3115/v1/d14-1162",
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": true,
#             "paperId": "0825788b9b5a18e3dfea5b0af123b5e939a4f564",
#             "title": "Glove: Global Vectors for Word Representation",
#             "url": "https://www.semanticscholar.org/paper/0825788b9b5a18e3dfea5b0af123b5e939a4f564",
#             "venue": "EMNLP",
#             "year": 2014
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "2298649",
#                     "name": "Oren Melamud",
#                     "url": "https://www.semanticscholar.org/author/2298649"
#                 },
#                 {
#                     "authorId": "34508613",
#                     "name": "Jacob Goldberger",
#                     "url": "https://www.semanticscholar.org/author/34508613"
#                 },
#                 {
#                     "authorId": "7465342",
#                     "name": "Ido Dagan",
#                     "url": "https://www.semanticscholar.org/author/7465342"
#                 }
#             ],
#             "doi": "10.18653/v1/k16-1006",
#             "intent": [
#                 "methodology",
#                 "background"
#             ],
#             "isInfluential": true,
#             "paperId": "59761abc736397539bdd01ad7f9d91c8607c0457",
#             "title": "context2vec: Learning Generic Context Embedding with Bidirectional LSTM",
#             "url": "https://www.semanticscholar.org/paper/59761abc736397539bdd01ad7f9d91c8607c0457",
#             "venue": "CoNLL",
#             "year": 2016
#         },
#         {
#             "arxivId": "1511.08308",
#             "authors": [
#                 {
#                     "authorId": "36409676",
#                     "name": "Jason P. C. Chiu",
#                     "url": "https://www.semanticscholar.org/author/36409676"
#                 },
#                 {
#                     "authorId": "143662759",
#                     "name": "Eric Nichols",
#                     "url": "https://www.semanticscholar.org/author/143662759"
#                 }
#             ],
#             "doi": "10.1162/tacl_a_00104",
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "10a4db59e81d26b2e0e896d3186ef81b4458b93f",
#             "title": "Named Entity Recognition with Bidirectional LSTM-CNNs",
#             "url": "https://www.semanticscholar.org/paper/10a4db59e81d26b2e0e896d3186ef81b4458b93f",
#             "venue": "Transactions of the Association for Computational Linguistics",
#             "year": 2015
#         },
#         {
#             "arxivId": "cs/0306050",
#             "authors": [
#                 {
#                     "authorId": "145157221",
#                     "name": "Erik F. Tjong Kim Sang",
#                     "url": "https://www.semanticscholar.org/author/145157221"
#                 },
#                 {
#                     "authorId": "2105414",
#                     "name": "Fien De Meulder",
#                     "url": "https://www.semanticscholar.org/author/2105414"
#                 }
#             ],
#             "doi": "10.3115/1119176.1119195",
#             "intent": [
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "1058b84457615a98fadbb4afac59f2fa2bc2da98",
#             "title": "Introduction to the CoNLL-2003 Shared Task: Language-Independent Named Entity Recognition",
#             "url": "https://www.semanticscholar.org/paper/1058b84457615a98fadbb4afac59f2fa2bc2da98",
#             "venue": "CoNLL",
#             "year": 2003
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "49336604",
#                     "name": "Wenhui Wang",
#                     "url": "https://www.semanticscholar.org/author/49336604"
#                 },
#                 {
#                     "authorId": "144610884",
#                     "name": "Nan Yang",
#                     "url": "https://www.semanticscholar.org/author/144610884"
#                 },
#                 {
#                     "authorId": "49807919",
#                     "name": "Furu Wei",
#                     "url": "https://www.semanticscholar.org/author/49807919"
#                 },
#                 {
#                     "authorId": "39488576",
#                     "name": "Baobao Chang",
#                     "url": "https://www.semanticscholar.org/author/39488576"
#                 },
#                 {
#                     "authorId": "1702828",
#                     "name": "Ming Zhou",
#                     "url": "https://www.semanticscholar.org/author/1702828"
#                 }
#             ],
#             "doi": "10.18653/v1/p17-1018",
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "b798cfd967e1a9ca5e7bc995d33a907bf65d1c7f",
#             "title": "Gated Self-Matching Networks for Reading Comprehension and Question Answering",
#             "url": "https://www.semanticscholar.org/paper/b798cfd967e1a9ca5e7bc995d33a907bf65d1c7f",
#             "venue": "ACL",
#             "year": 2017
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "1814094",
#                     "name": "Greg Durrett",
#                     "url": "https://www.semanticscholar.org/author/1814094"
#                 },
#                 {
#                     "authorId": "38666915",
#                     "name": "Dan Klein",
#                     "url": "https://www.semanticscholar.org/author/38666915"
#                 }
#             ],
#             "doi": null,
#             "intent": [],
#             "isInfluential": false,
#             "paperId": "3054726d298d3c5f7b95b224e4e5b17d88068c3f",
#             "title": "Easy Victories and Uphill Battles in Coreference Resolution",
#             "url": "https://www.semanticscholar.org/paper/3054726d298d3c5f7b95b224e4e5b17d88068c3f",
#             "venue": "EMNLP",
#             "year": 2013
#         },
#         {
#             "arxivId": null,
#             "authors": [
#                 {
#                     "authorId": "3106437",
#                     "name": "Alessandro Raganato",
#                     "url": "https://www.semanticscholar.org/author/3106437"
#                 },
#                 {
#                     "authorId": "3257579",
#                     "name": "Claudio Delli Bovi",
#                     "url": "https://www.semanticscholar.org/author/3257579"
#                 },
#                 {
#                     "authorId": "1733928",
#                     "name": "Roberto Navigli",
#                     "url": "https://www.semanticscholar.org/author/1733928"
#                 }
#             ],
#             "doi": "10.18653/v1/d17-1120",
#             "intent": [
#                 "background",
#                 "methodology"
#             ],
#             "isInfluential": false,
#             "paperId": "fb166f1e77428a492ea869a8b79df275dd9669c2",
#             "title": "Neural Sequence Learning Models for Word Sense Disambiguation",
#             "url": "https://www.semanticscholar.org/paper/fb166f1e77428a492ea869a8b79df275dd9669c2",
#             "venue": "EMNLP",
#             "year": 2017
#         }
#     ],
#     "title": "Deep contextualized word representations",
#     "topics": [
#         {
#             "topic": "Sentiment analysis",
#             "topicId": "6011",
#             "url": "https://www.semanticscholar.org/topic/6011"
#         },
#         {
#             "topic": "Question answering",
#             "topicId": "18817",
#             "url": "https://www.semanticscholar.org/topic/18817"
#         },
#         {
#             "topic": "Bidirectional transformation",
#             "topicId": "134320",
#             "url": "https://www.semanticscholar.org/topic/134320"
#         },
#         {
#             "topic": "Textual entailment",
#             "topicId": "162051",
#             "url": "https://www.semanticscholar.org/topic/162051"
#         },
#         {
#             "topic": "Text corpus",
#             "topicId": "14829",
#             "url": "https://www.semanticscholar.org/topic/14829"
#         },
#         {
#             "topic": "Context-sensitive language",
#             "topicId": "5057",
#             "url": "https://www.semanticscholar.org/topic/5057"
#         },
#         {
#             "topic": "Language model",
#             "topicId": "26812",
#             "url": "https://www.semanticscholar.org/topic/26812"
#         },
#         {
#             "topic": "Word embedding",
#             "topicId": "286696",
#             "url": "https://www.semanticscholar.org/topic/286696"
#         },
#         {
#             "topic": "Experiment",
#             "topicId": "378",
#             "url": "https://www.semanticscholar.org/topic/378"
#         },
#         {
#             "topic": "Downstream (software development)",
#             "topicId": "10055",
#             "url": "https://www.semanticscholar.org/topic/10055"
#         },
#         {
#             "topic": "Semiconductor industry",
#             "topicId": "76540",
#             "url": "https://www.semanticscholar.org/topic/76540"
#         },
#         {
#             "topic": "Natural language processing",
#             "topicId": "1914",
#             "url": "https://www.semanticscholar.org/topic/1914"
#         },
#         {
#             "topic": "ENCODE",
#             "topicId": "365717",
#             "url": "https://www.semanticscholar.org/topic/365717"
#         }
#     ],
#     "url": "https://www.semanticscholar.org/paper/3febb2bed8865945e7fddc99efd791887bb7e14f",
#     "venue": "NAACL-HLT",
#     "year": 2018
# }

# %%
# lets create the string object to dictionary so that we can access the key,values from the dictionary.Further we create the DataFrame.
my_dict = json.loads(content)

authors = my_dict["authors"]
citation_vel = my_dict["citationVelocity"]
citations = my_dict["citations"]

#Creates DataFrame object from dictionary by columns using pandas.DataFrame.from_dict()
#create dataframe of authors 
auth_df = pd.DataFrame.from_dict(authors)
auth_df=auth_df.drop(columns=['authorId','url'])

#create dataframe of citations, then get the list of papers which cite this paper.We use title of paper and intent assuming that intent means where exactly the peper is cited in this paper.
citations_df = pd.DataFrame.from_dict(citations)
paper_df = citations_df[['title', 'intent','url']]
paper_url = citations_df[['url', 'paperId', 'arxivId' ]]
paper_arxivId = citations_df[['arxivId' ]]
paper_df
paper_url
#paper_arxivId
#auth_df
# Out:
#                                                    url  \
# 0    https://www.semanticscholar.org/paper/fea13dcb...
# 1    https://www.semanticscholar.org/paper/425e249c...
# 2    https://www.semanticscholar.org/paper/fca28d8d...
# 3    https://www.semanticscholar.org/paper/68acfb44...
# 4    https://www.semanticscholar.org/paper/8492269d...
# 5    https://www.semanticscholar.org/paper/bd40bc8f...
# 6    https://www.semanticscholar.org/paper/39c4e608...
# 7    https://www.semanticscholar.org/paper/7db30882...
# 8    https://www.semanticscholar.org/paper/69ab4622...
# 9    https://www.semanticscholar.org/paper/61d24c45...
# 10   https://www.semanticscholar.org/paper/6b170d8b...
# 11   https://www.semanticscholar.org/paper/ee6c929b...
# 12   https://www.semanticscholar.org/paper/658721bc...
# 13   https://www.semanticscholar.org/paper/fca6b04c...
# 14   https://www.semanticscholar.org/paper/7b38c23d...
# 15   https://www.semanticscholar.org/paper/57032c1e...
# 16   https://www.semanticscholar.org/paper/2785d561...
# 17   https://www.semanticscholar.org/paper/f3a78149...
# 18   https://www.semanticscholar.org/paper/18e073e4...
# 19   https://www.semanticscholar.org/paper/e814ee99...
# 20   https://www.semanticscholar.org/paper/4d7d9558...
# 21   https://www.semanticscholar.org/paper/9fc0ddd6...
# 22   https://www.semanticscholar.org/paper/770c0e3a...
# 23   https://www.semanticscholar.org/paper/e3567830...
# 24   https://www.semanticscholar.org/paper/8e15ce5a...
# 25   https://www.semanticscholar.org/paper/2c063484...
# 26   https://www.semanticscholar.org/paper/5d469c46...
# 27   https://www.semanticscholar.org/paper/c3a2623c...
# 28   https://www.semanticscholar.org/paper/ea00a63c...
# 29   https://www.semanticscholar.org/paper/5f994dc8...
# ..                                                 ...
# 969  https://www.semanticscholar.org/paper/a90f1b6d...
# 970  https://www.semanticscholar.org/paper/256694f2...
# 971  https://www.semanticscholar.org/paper/69b83a52...
# 972  https://www.semanticscholar.org/paper/2fa45a5b...
# 973  https://www.semanticscholar.org/paper/251e1f92...
# 974  https://www.semanticscholar.org/paper/1ee2f2b3...
# 975  https://www.semanticscholar.org/paper/e6afaa76...
# 976  https://www.semanticscholar.org/paper/977aa397...
# 977  https://www.semanticscholar.org/paper/5df025fb...
# 978  https://www.semanticscholar.org/paper/8eed5f0d...
# 979  https://www.semanticscholar.org/paper/6084b58d...
# 980  https://www.semanticscholar.org/paper/3ed13df8...
# 981  https://www.semanticscholar.org/paper/ab8a005d...
# 982  https://www.semanticscholar.org/paper/7442a18a...
# 983  https://www.semanticscholar.org/paper/382852f0...
# 984  https://www.semanticscholar.org/paper/51004bc6...
# 985  https://www.semanticscholar.org/paper/a7f30bae...
# 986  https://www.semanticscholar.org/paper/9d11c8fe...
# 987  https://www.semanticscholar.org/paper/bfa99112...
# 988  https://www.semanticscholar.org/paper/e924f7be...
# 989  https://www.semanticscholar.org/paper/b69538f0...
# 990  https://www.semanticscholar.org/paper/3f72fa91...
# 991  https://www.semanticscholar.org/paper/2f25629b...
# 992  https://www.semanticscholar.org/paper/cb0f3ee1...
# 993  https://www.semanticscholar.org/paper/fb73b93d...
# 994  https://www.semanticscholar.org/paper/f48ae425...
# 995  https://www.semanticscholar.org/paper/256016cd...
# 996  https://www.semanticscholar.org/paper/2c5ec74f...
# 997  https://www.semanticscholar.org/paper/33b0a849...
# 998  https://www.semanticscholar.org/paper/1536e895...
#
#                                       paperId     arxivId
# 0    fea13dcb73f9754ca498ef700769ec21793e6870  1905.05538
# 1    425e249c1c91128c016d27ce353540aed19eea7e        None
# 2    fca28d8de84cae5bc8f48cb8cfc5cedf106f62a1  1808.06305
# 3    68acfb44aed9a138b0693facadda025d90693f61  1904.12683
# 4    8492269d2bb474d57d6def97efcf86c42735554a  1908.03548
# 5    bd40bc8f5b32f3b72495c5fdd83719796a212cd1        None
# 6    39c4e6082cca859d9277af126b6c7d3418da27c1        None
# 7    7db308823bdd2b297da2c56096c5dd57b65c6152  1906.07854
# 8    69ab4622c2cad8a6e03c5061cb1a563e57ff0e31        None
# 9    61d24c45e41f4f6cfc3d9da2f03efde1862b839e  1904.00585
# 10   6b170d8b06f5272422807e0afa159699cf4a2bdd        None
# 11   ee6c929b5829c735170e3ef07038f60a9de12d1d        None
# 12   658721bc13b0fa97366d38c05a96bf0a9f4bb0ac  1901.11504
# 995  256016cdd603a89b18d345dbc71981a3f77cd25c  1908.02282
# 996  2c5ec74fb56fbfbceaa4cd5c8312ada4e2e19503  1905.05529
# 997  33b0a849138062b3806bc72f9769bc8dfe434193        None
# 998  1536e8958697c5364f68b2e2448905dbbeb3a0ca  1809.02789
#
# [999 rows x 3 columns]

# %%
paper_arxivId = citations_df[['arxivId' ]].head(10)

# %% [markdown]
# ## Download PDF version of papers
# A PDF version for each of these papers. To obtain this, we can download them directly from arxiv: https://arxiv.org/pdf/[arxiv ID].pdf, for example: https://arxiv.org/pdf/1907.04829.pdf

# %%
# !rm -f input/*

# %%
import requests
from multiprocessing.pool import ThreadPool
import os

def download_url(url):
    print("downloading: ",url)
    # assumes that the last segment after the / represents the file name
    # if url is abc/xyz/file.txt, the file name will be file.txt
    file_name_start_pos = url.rfind("/") + 1
    file_name = url[file_name_start_pos:]
    file_path = os.path.join('./input', file_name)
 
    r = requests.get(url, stream=True)
    if r.status_code == requests.codes.ok:
        with open(file_path, 'wb') as f:
            for data in r:
                f.write(data)
    return url
        
arxiv_ids = [a_id for a_id in citations_df['arxivId'] if a_id is not None]
urls = [f'https://arxiv.org/pdf/{a_id}.pdf' for a_id in arxiv_ids]

urls = urls[:999]
print(f"{len(urls)} files to be downloaded.")

# Run 5 multiple threads. Each call will take the next element in urls list
results = ThreadPool(5).imap_unordered(download_url, urls)
for r in results:
    print(r)
# Out:
# 605 files to be downloaded.
# downloading:  https://arxiv.org/pdf/1905.05538.pdf
# downloading:  https://arxiv.org/pdf/1808.06305.pdf
# downloading:  https://arxiv.org/pdf/1904.12683.pdf
# downloading:  https://arxiv.org/pdf/1908.03548.pdf
# downloading:  https://arxiv.org/pdf/1906.07854.pdf
# downloading: https://arxiv.org/pdf/1808.06305.pdf
#  https://arxiv.org/pdf/1904.00585.pdf
# downloading:  https://arxiv.org/pdf/1901.11504.pdf
# https://arxiv.org/pdf/1904.12683.pdf
# downloading: https://arxiv.org/pdf/1905.05538.pdf
#  https://arxiv.org/pdf/1810.05201.pdf
# downloading: https://arxiv.org/pdf/1908.03548.pdf
#  https://arxiv.org/pdf/1906.05149.pdf
# downloading: https://arxiv.org/pdf/1906.07854.pdf
#  https://arxiv.org/pdf/1905.10892.pdf
# downloading: https://arxiv.org/pdf/1904.00585.pdf https://arxiv.org/pdf/1811.08705.pdf
#
# downloading:  https://arxiv.org/pdf/1902.10985.pdf
# https://arxiv.org/pdf/1810.05201.pdf
# downloading: https://arxiv.org/pdf/1901.11504.pdf https://arxiv.org/pdf/1808.09147.pdf
#
# downloading:  https://arxiv.org/pdf/1907.12108.pdf
# https://arxiv.org/pdf/1906.05149.pdf
# downloading:  https://arxiv.org/pdf/1905.11833.pdf
# https://arxiv.org/pdf/1905.10892.pdf
# downloading:  https://arxiv.org/pdf/1905.00078.pdf
# https://arxiv.org/pdf/1811.08705.pdf
# downloading: https://arxiv.org/pdf/1902.10985.pdf
#  https://arxiv.org/pdf/1811.08610.pdf
# downloading:  https://arxiv.org/pdf/1905.07129.pdf
# ../input/1811.12891.pdf
# ../input/1907.11769.pdf
# ../input/1906.07544.pdf
# ../input/1904.03371.pdf
# ../input/1809.01682.pdf
# ../input/1808.09861.pdf
# ../input/1811.02076.pdf
# ../input/1908.06725.pdf
# ../input/1906.02762.pdf
# ../input/1908.05760.pdf
# ../input/1901.02262.pdf
# ../input/1905.05950.pdf
# ../input/1908.10423.pdf
# ../input/1906.00363.pdf
# ../input/1904.08608.pdf
# ../input/1809.09194.pdf
# ../input/1906.05226.pdf
# ../input/1907.02884.pdf
# ../input/1810.08854.pdf
# ../input/1904.08386.pdf
# ../input/1903.03260.pdf
# ../input/1904.09675.pdf
# ../input/1908.06136.pdf
# ../input/1806.03822.pdf
# ../input/1808.09653.pdf
# ../input/1810.13327.pdf
# ../input/1907.06214.pdf
# ../input/1904.04153.pdf
# ../input/1907.13625.pdf
# ../input/1808.03815.pdf
# ../input/1907.09669.pdf
# ../input/1811.08610.pdf
# ../input/1808.10128.pdf
# ../input/1906.07592.pdf
# ../input/1810.07150.pdf
# runtime: 331.248 seconds

# %%
# run only once
# import nltk
# nltk.download('punkt')

# %%
import xml.etree.ElementTree as ET

def match_all_bib_nodes(curr_node, acc):
    new_list = []
    if curr_node.tag == '{http://www.tei-c.org/ns/1.0}biblStruct':
        new_list += [curr_node]
    else:
        children = list(curr_node)
        for child in children:
            new_list += match_all_bib_nodes(child, acc)
    return acc + new_list

def get_title_node(curr_node):
    if curr_node.tag == '{http://www.tei-c.org/ns/1.0}title':
        return curr_node
    else:
        children = list(curr_node)
        for child in children:
            n = get_title_node(child)
            if n is not None:
                return n
        return None
    
def get_ref(bib_node):
    ID_KEY = '{http://www.w3.org/XML/1998/namespace}id'
    if ID_KEY not in bib_node.attrib.keys():
        return None
    else:
        return bib_node.attrib[ID_KEY]

from difflib import SequenceMatcher

def get_matching_score(title1: str, title2: str) -> float:
    return SequenceMatcher(None, 
                           title1.strip().lower(), 
                           title2.strip().lower()
                          ).ratio()

    
def get_citation_number(title, root):
    try:
        bib_nodes = match_all_bib_nodes(root, [])
        THRESHOLD = 0.98
        titles_by_ref = {
            get_ref(n): get_title_node(n).text
            for n in bib_nodes
            if get_ref(n) is not None and get_title_node(n).text is not None
        }
        scores = {
            k: get_matching_score(title, item)
            for k, item in titles_by_ref.items()
        }
        max_key = max(scores, key=scores.get)
        if scores[max_key] > THRESHOLD:
            return max_key, titles_by_ref[max_key]
        else:
            return None, None
    except Exception as inst:
        return None, None

def get_xml_node(xmlpath: str):
    tree = ET.parse(xmlpath)
    root = tree.getroot()
    return root

import xml.etree.ElementTree as ET
def find_ref_nodes(curr, ref):
    if match_ref_node(curr, ref):
        return [curr]
    children = list(curr)
    matched_nodes = []
    for child in children:
        newfound = find_ref_nodes(child, ref)
        matched_nodes += newfound
    return matched_nodes

def match_ref_node(curr_node, ref):
    return curr_node.tag == '{http://www.tei-c.org/ns/1.0}ref' and \
           'target' in curr_node.attrib and \
           curr_node.attrib['target'] == f'#{ref}'

def get_ref_paragraph(ref_node, root):
    parent_map = dict((c, p) for p in root.getiterator() for c in p)
    parent = parent_map[ref_node]
    sentences = ''.join([parent.text] + ['<REF>'] + [n.tail for n in list(parent) if n.tail is not None])
    return sentences

def get_paragraphs_by_filepath(xmlpath: str, title: str):
    root = get_xml_node(xmlpath)
    ref, _ = get_citation_number(title, root)
    ref_nodes = find_ref_nodes(root, ref)
    sentences = [
        get_ref_paragraph(rn, root) for rn in ref_nodes
    ]
    return sentences

# xmlpath = "output_style_transfer/4eece2039e953d4403ca2199d996469e877b.tei.xml"
# get_sentences_by_filepath(xmlpath, title)

from os import listdir
from os.path import isfile, join

def get_xml_files_in_dir(xmldir: str):
    onlyfiles = [join(xmldir, f) for f in listdir(xmldir) if isfile(join(xmldir, f))]
    return onlyfiles

import nltk

from nltk.tokenize import sent_tokenize
def extract_ref_sentence_from_paragraph(para: str, ref_token = '<REF>'):
    sentences = nltk.sent_tokenize(para)
    sentences_containing_ref = [s for s in sentences if ref_token in s]
    return sentences_containing_ref[0]

def get_first_n_ref_sentences_by_dir(n: int, xmldir: str, title: str):
    xmlfiles = get_xml_files_in_dir(xmldir)
    paragraph_set = [
         get_paragraphs_by_filepath(xmlf, title) for xmlf in xmlfiles
    ]
    mention_para_groups = [
        paragraphs[0:n] for paragraphs in paragraph_set if len(paragraphs) > 0
    ]
#     return mention_para_groups
    first_mention_sentences = [
        extract_ref_sentence_from_paragraph(para) 
        for para_group in mention_para_groups
        for para in para_group
    ]
    return first_mention_sentences


xmldirpath = './output'
title = my_dict['title']
NUMBER_OF_SENTENCES_PER_PAPER = 5

x = get_first_n_ref_sentences_by_dir(NUMBER_OF_SENTENCES_PER_PAPER, xmldirpath, title)
x
# Out:
# ['For Question Match and ESIM we also experiment with ELMo <REF> which improved their score on Test with 0.4% and 1.8%.',
#  'One of the greatest opportunities for further gains is through the use of context-sensitive word embeddings, such as ELMo <REF> and ULMfit .',
#  'Modern deep learning algorithms often do away with feature engineering and learn latent representations directly from raw data that are given as input to Deep Neural Networks (DNNs) <REF>.',
#  "Other variants have been proposed since Word2vec's initial public release, such as GloVe <REF>, ELMo , and BERT .",
#  'Language Modeling recently gained in importance as it is being used as a base for transfer learning in multiple supervised tasks, obtaining impressive improvements over state-of-the-art <REF>.',
#  'Natural language processing tasks show the best performance when transfer learning is applied either from an LSTM language model <REF> or from selfattention language models .',
#  'Another approach to address inflections in Polish is to use byte pair encoding <REF>, character level language models  or unigram subword tokenization .',
#  'In recent years, transfer learning has achieved amazing performance on many NLP tasks <REF>.',
#  '<REF> illustrates the deep contextualized representations learned.',
#  '<REF> illustrates the deep contextualized representations learned.',
#  'While most of the above models except for the recurrent-neural net abased models above are shallow our model DOLORES differs from all of these works and especially that of <REF> in that we learn deep contextualized knowledge graph representations of entities and relations using a deep neural sequential model.',
#  'While most of the above models except for the recurrent-neural net abased models above are shallow our model DOLORES differs from all of these works and especially that of <REF> in that we learn deep contextualized knowledge graph representations of entities and relations using a deep neural sequential model.',
#  'While, traditionally this has been modeled using count-based "ngram based" models <REF>, recently deep neural models like LSTMs and RNN\'s have been used to build such language models.',
#  'Thus, we disregard common word embeddings and construct genuinely synonymous sentences based on Wordnet <REF> synonyms end context dependent ELMO  embeddings that are later on validated by human annotators and corrected.',
#  'Deep language representations, on the other hand, have shown to be a very effective form of unsupervised pre-training, yielding contextualized features that capture linguistic properties and benefit downstream natural language understanding tasks, such as semantic role labeling, coreference resolution, and sentiment analysis <REF>.',
#  'This is confirmed by the superior performance on TACRED <REF> when entity and grammatical role information is provided (NE+GR).',
#  '<REF> introduced embeddings from language models (ELMo), an approach to learn contextualized word representations by training a bidirectional LSTM to optimize a language model objective.',
#  '<REF> introduced embeddings from language models (ELMo), an approach to learn contextualized word representations by training a bidirectional LSTM to optimize a language model objective.',
#  'While we can observe useful correlations in the row vectors built for the IMDB dataset, language models like word2vec are notoriously difficult to interpret <REF>.',
#  'On the other hand work such as ELMo <REF> and BERT  propose deeply connected layers to learn sentence embeddings by exploiting bi-directional contexts.',
#  'We consider three NLI systems based on deep neural networks: Decomposable Attention (DA) <REF>, ESIM , and a Finetuned Transformer Language Model (FTLM) .',
#  'In order to generate an appropriate response, a system must be able to aggregate information over multiple turns, such as estimating a belief state over user goals <REF> and resolving anaphora co-references .',
#  'The second step is to fine-tune this pretrained model on a specific downstream task using a much smaller in-domain dataset <REF>.',
#  'NUR has been extensively explored both as an independent task <REF> and as an auxiliary loss in a multi-tasking setup .',
#  'In light of this, ELMo <REF> was proposed to addresses this problem.',
#  'Based on the properties of the items displayed, embedding strategies described in <REF> have been shown to correlate with human perception.',
#  'We apply the proposed system on three datasets from different domains -SQuAD <REF>, TriviaQA-Web  and the BioASQ challenge .',
#  'Motivated by the desire to address the limitations of supervised parsing and by the success of large-scale unsupervised modeling such as ELMo and BERT <REF> Equal contribution, randomly ordered.',
#  'Pre-trained sentence encoders such as ELMo <REF> and BERT  have rapidly improved the state of the art on many NLP tasks, and seem poised to displace both static word embeddings  and discrete pipelines  as the basis for natural language processing systems.',
#  'Additionally, in <REF>.1 we show scalar mixing weights for the ELMo encoder , which consists of two LSTM layers over a per-word character CNN.',
#  'Additionally, in <REF>.1 we show scalar mixing weights for the ELMo encoder , which consists of two LSTM layers over a per-word character CNN.',
#  'In our experiments, we make use of ELMo embeddings <REF> which are contextualised and token-based as opposed to  type-based word representations like word2vec or GLoVe where each word type is assigned a single vector.',
#  'For our models, we used a TFIDF <REF>, a 2-layer LSTM , and the state-of-the-art BERT model .',
#  'A number of datasets have been proposed to study the coreference resolution problem, such as MUC <REF>, ACE , and OntoNotes .',
#  'We test a state-of-the-art system <REF> on PreCo and get an F1 score of 81.5.',
#  'We show that in a state-of-the-art coreference resolution system <REF>, we can improve the model performance from 77.3 to 81.6 F1 on a training set of 2.5K PreCo documents by using an oracle mention detector, and the remaining gap of 18.4 F1 to the perfect 100 F1 can only be reduced by improving mention clustering.',
#  'The first two resources for coreference resolution study were MUC-6 and MUC-7 <REF>  .',
#  'We use the end-to-end neural coreference resolver, E2E-Coref <REF>, enhanced by the deep contextualized word representations ) as the baseline system, and we refer to this system as EE2E-Coref.',
#  'Modern neural architectures for NLP are highly effective when provided a large amount of labelled training data <REF>.',
#  'Pretrained Language Models <REF> investigate different methods to transfer knowledge to supervised recurrent neural networks.',
#  'Pretrained Language Models <REF> investigate different methods to transfer knowledge to supervised recurrent neural networks.',
#  'LMs are pretrained using the architecture proposed by <REF> with hyperparameters in ).',
#  'LMs are pretrained using the architecture proposed by <REF> with hyperparameters in ).',
#  'We evaluate the performance of our spanbased model on the <REF> datasets .',
#  '• Typical word embeddings, SENNA 6 (Collobert et al., 2011) • Contextualized word embeddings, ELMo 7 <REF> SENNA and ELMo can be regarded as different types of embeddings in terms of the context sensitivity.',
#  'Word representations Typical word representations, such as SENNA <REF> and GloVe , have been used and contributed to the performance improvement .',
#  'Word representation setup As word embeddings x word , we use two types of embeddings, (i) SENNA <REF>, 50-dimensional word vectors (d word = 50), and (ii) ELMo , 1024-dimensional vectors (d word = 1024).',
#  'This past year has seen tremendous progress in building general purpose models that can learn good language representations across a range of tasks and domains <REF>.',
#  'These word embeddings were further improved by FastText <REF> with the inclusion of character n-grams.',
#  'At the recent VU Amsterdam (VUA) metaphor identification shared task <REF>, neural approaches dominated, with most teams using LSTMs trained on word embeddings and additional linguistic features, such as semantic classes and part of speech tags .',
#  'ELMo Finally, we use ELMo, a model of deep contextualized word embeddings <REF>.',
#  '7 At submission time we observe a recent short arXiv paper <REF>, available on August 28th, showing an accuracy of 67.6 using ELMo , which is the only result better than ours.',
#  'In this work we focus on the particular NLP area of word embeddings <REF>, which represent words in a numerical vector space.',
#  'Pretrained Language Models (LM) like ULMfit <REF>, ELMo , OpenAI GPT  and BERT , proposed different neural language model architectures and made their pre-trained weights available to ease the application of transfer learning to downstream tasks, where they have pushed the state-of-the-art for several benchmarks including question answering on SQuAD, NLI, cross-lingual NLI and named identity recognition (NER).',
#  'Among different approaches to contextualized word embeddings (mentioned in section 2), we choose ELMo <REF> as contextualized word embedding approach.',
#  'There is a research trend on word and sentence embeddings after the invention of Word2Vec <REF>.',
#  'In this section, we briefly review BERT (Bidirectional Encoder Representation from Transformers <REF>), which is one of the key innovations of unsupervised contextualized representation learning .',
#  'The idea behind these innovations is that although the word embedding <REF> layer is trained from large-scale corpora, relying on the limited supervised data from end-tasks to train the contextualized representation is insufficient.',
#  'In recent years, there has been an increase in the number of annotated RC datasets such as SQuAD <REF>, NewsQA , TriviaQA  and RACE 8 Early testing of our model was actually done on SQuAD.',
#  'The paucity of data for both emotion recognition and empathetic response generation <REF>.',
#  'Detecting sentiment and emotion <REF>    proposed a new benchmark for empathetic dialogue generation, which is grounded in a situation prompted by specific emotion labels.',
#  'Specifically, we employ deep contextualized word representations using the language model ELMo <REF>.',
#  'Here, it is achieved with contextual embedding methods <REF> that embed each token based on both the token itself and its context.',
#  'Learning distributed representations of words has been studied extensively in the past few years <REF>.',
#  'We also demonstrate that the learned graphs are generic enough to work with various sets of features on which the graphs have not been trained, including GloVe embeddings <REF>, ELMo embeddings , and taskspecific RNN states.',
#  'Sequence prediction As opposed to predicting just the immediate next unit <REF>, we predict the context of length up to D. This gives stronger training signals to the unsupervised learner.',
#  'The mixture weights m l G and m l Λ can be instantiated as Softmax-normalized parameters <REF> or can be conditioned on the features H. To transfer the mixed latent graph, we again adopt the weighted sum operation as in Eq.',
#  'In our implementation, at position t, in addition to predicting the forward context (x t+1 , · · · , x t+D ), we also use a separate network to predict the backward context (x t−D , · · · , x t−1 ), similar to <REF>.',
#  'Respectively, we experimented with coupling the two networks, removing the ReLU activations, using only a single layer of graphs, using a sentence-level Skip-thought objective <REF>, and reducing the context length to one .',
#  'We compare against the reported results of ESIM <REF> and  in the original paper.',
#  'Fine-Tuning BERT This is another extractive RC model that benefits from the recent advance in pretrained general language encoders <REF>.',
#  'Pre-trained LM To take advantage of the recent success in pre-trained language models <REF> we also make use of ELMo contextualized embeddings instead of the embedding matrix and the character LSTM concatentation.',
#  'The final models accuracies are summarized in <REF>.',
#  'The span identification component of our task overlaps with the coreference one (see <REF> for a thorough summary on the Noun Phrase coreference resolution and  for a comparison between coreference and anaphora).',
#  'Extreme summarization revisits interesting problems in abstractive summarization with the relatively simpler objective of generating single sentence summaries rather than multiline summaries <REF>.',
#  'Among the most popular and widely used word embeddings are word2vec <REF>, GloVe  and ELMO .',
#  'In this work we use a multi-layer bi-directional LSTM network as encoder, similar to ELMo <REF>.',
#  'Recently contextual text representation models like ELMo <REF>, BERT  and OpenAI GPT  have pushed the state-of-the-art results of various NLP tasks.',
#  'Word Embedding Models: Most algorithms for learning embeddings take inspiration from language modeling <REF>, motivated by distributional hypothesis , and employ a shallow neural network to map the words into a low dimensional space.',
#  'These word embeddings are typically trained on large corpora using embedding approaches which capture information concerning words that commonly appear together <REF>.',
#  'Most of such approaches, including those used in previous studies on dialog act recognition, generate embeddings for each word independently of its context <REF>.',
#  'However, the meaning of a word and, consequently, how it contributes for the meaning of a segment, is highly influenced by both its sense and context <REF>.',
#  'However, the meaning of a word and, consequently, how it contributes for the meaning of a segment, is highly influenced by both its sense and context <REF>.',
#  'The first, ELMo <REF>, is based on a stack of two bi-directional LSTMs and was the first approach used to generate contextualized representations.',
#  'ELMo <REF>, a state-of-the-art contextsensitive NLM, is fine-tuned on a large credibility-focused social media corpus and used to encode tweets.',
#  'We adopt the ELMo biLM model <REF> in our experiments.',
#  'ELMo provides deep, contextualized, and character-based word representations by using bidirectional language models (biLMs) <REF>.',
#  'ELMo provides deep, contextualized, and character-based word representations by using bidirectional language models (biLMs) <REF>.',
#  'Contextual word representations have recently been used to achieve state-of-the-art performance across a range of language understanding tasks <REF>.',
#  'Contextual word representations have recently been used to achieve state-of-the-art performance across a range of language understanding tasks <REF>.',
#  'Encoder Layers As shown in Row 4 of <REF>, applying EM routing to all encoder layers significantly decreases the training speed by 37.5%, which is not acceptable since TRANSFORMER is best known for both good performance and quick training.',
#  'A comprehensive source for articles on this topic is the PubMed <REF> platform, combining over 29 million citations while providing access to their metadata.',
#  'These word vectors models use multiple different pre-training sources, for instance, Word2Vec <REF> uses English Wikipedia, and BERT  uses both English Wikipedia and BooksCorpus.',
#  'Recent work on language understanding has demonstrated the effectiveness of pretraining neural networks on large corpora using unsupervised objectives such as language modelling, and then fine-tuning the resulting models on downstream target tasks <REF>.',
#  'One property is that unlike texts which naturally use neighboring words/sentences as context <REF>, categorical information stands alone and thus does not have information aside from itself.',
#  'In this section we look at replacing statically pretrained embeddings with contextual embeddings, namely Elmo <REF>.',
#  'ELMo <REF> is based on recurrent neural networks language models.',
#  'style preservation for style transfer, <REF> summary length for summarization, or relevancy for dialogue.',
#  'In recent years, deep learning techniques <REF> is applied to semantic parsing  [8] .',
#  'The context surrounding a mention may indicate its compatibility with other candidate mentions <REF>.',
#  '<REF>, it lacks a solid theoretical grounding.',
#  'We borrow the idea of involving a hierarchical neural networks structure <REF>.',
#  'To do so, we use deep contextualized word representations, which have recently been used to achieve the state of the art on six NLP tasks, including sentiment analysis <REF>.',
#  'Consequently, our architecture is based on Embeddings from Language Model or ELMo <REF>.',
#  'Ostensibly, this appears to be true: <REF> show that using pretrained deep word representations achieves state of the art on a variety of tasks.',
#  'With our approach, a shallow BiLSTMbased model achieves results comparable to Embeddings from Language Models (ELMo; <REF>, but uses around 100 times fewer parameters and performs inference 15 times faster.',
#  'Recently, <REF> introduce Embeddings from Language Models (ELMo), an approach for learning high-quality, deep contextualized representations using bidirectional language models.',
#  'ELMo, or Embeddings from Language Models, <REF> are deep contextualized word representations.',
#  'Opportunities for future work include a) comparing the results of our model to other existing dynamic embedding models, particularly when the attribute of interest is temporal in nature, b) exploring embeddings defined with respect to other attributes of interest, perhaps in combination with other contextual embedding models like <REF>, c) exploring alternative definitions of bias towards refugees and other groups, and d) learning a dynamic embedding model for continuous attributes in order to limit the need to impose (perhaps arbitrary) discretizations.',
#  'An alternative is the model-and taskindependent route of incorporating linguistic resources via word embeddings that are retro-fitted <REF> or counterfitted  to such resources.',
#  'While XLU shows promising results for tasks such as cross-lingual document classification <REF>, there are very few, if any, XLU benchmarks for more difficult language understanding tasks like natural language inference.',
#  'Sentence Representation Learning Many approaches have been proposed to extend word embeddings to sentence or paragraph representations <REF>.',
#  'To model texts into vector space, the input tokens are represented as embeddings in deep learning models <REF>.',
#  '2) Query-style: The Stanford Question Answering Dataset (SQuAD) <REF> contains 100k+ crowd sourced question-answer pairs where the answer is a span in a given Wikipedia paragraph.',
#  'In recent years many methods have been proposed for vision-language tasks such as image and video captioning <REF>, multimodal retrieval , phrase grounding , and visual question answering .',
#  'To achieve further improvement in transfer learning, we combine our proposed sentence encoder with recently proposed contextualized word vectors <REF> and show that the combined sentence encoding approach outperforms the state-of-the-art universal sentence embeddings learned using large-scale multi-task learning .',
#  'We combine the multi-task learned sentence representations with contextualized word representations <REF>) that yields new state-of-the-art results on 5/10 transfer tasks.',
#  'Recent works on learning distributional sentence representations such that they capture the syntactic and semantic regularities within sentences range from models that compose of word embeddings <REF> to more complex neural network architectures .',
#  'A concurrent work <REF> propose to build general purpose sentence encoder by learning from a joint objective of classification, machine translation, parse tree generation and unsupervised skip-thought tasks.',
#  'With recent success of contextualized word vectors <REF> in many downstream NLP application, we are interested in investigating the utility of contextualized word vectors in our transfer learning setting.',
#  'We show that our embeddings can be added to existing cross-sentence inference models, such as BiDAF++ <REF> for  for NLI.',
#  'Advances in techniques and hardware for training deep neural networks have recently enabled impressive accuracy improvements across many fundamental NLP tasks <REF>, with the most computationally-hungry models obtaining the highest scores .',
#  'The ELMo model <REF> is based on stacked LSTMs and provides rich word representations in context by pre-training on a large amount of data using a language modeling objective.',
#  'The ELMo model <REF> is based on stacked LSTMs and provides rich word representations in context by pre-training on a large amount of data using a language modeling objective.',
#  'NLP has seen an upheaval in the last year, with contextual word embeddings, such as ELMo <REF> and BERT , setting state-of-the-art performance on many tasks.',
#  'Some existing models encode the semantic structures in the contexts implicitly during the entity representation learning <REF>.',
#  'In this section, we introduce three different methods for integrating external syntactic information into the neural SRL system <REF>): Baseline Our baseline system is a stacked bi-LSTM architecture .',
#  'Then, like its friends ELMo <REF>, BERT , and ERNIE , we can also use KERMIT for self-supervised representation learning for use in downstream NLP tasks.',
#  'We apply STILTs to three separate pretrained arXiv:1811.01088v2 [cs.CL] 27 Feb 2019 sentence encoders: BERT <REF>, GPT , and a variant of ELMo .',
#  'Pretrained Sentence Encoders We primarily study the impact of STILTs on three sentence encoders: BERT <REF>, GPT  and ELMo .',
#  'A ELMo on STILTs Experiment setup We use the same architecture as <REF> for the non-task-specific parameters.',
#  'Recent breakthroughs of language models (LM) pre-trained on large corpora like ELMo <REF> and BERT  clearly show that unsupervised LM pre-training can vastly improve performance of downstream models.',
#  'Contextualized word embeddings: Recently, contextualized word representations pre-trained by large corpora like ELMo <REF> and BERT  significantly improve the performance of various NLP tasks.',
#  'Several human-annotated datasets are available for supervised WSD <REF>.',
#  'For the word embedding, we apply deep contextualized word representations (ELMO) from <REF> and allow them to be fine-tuned during the training.',
#  'Using a bi-attentive classification network <REF> as the encoder, out final model gives the best results on SST.',
#  'To show the universality of our approaches, we also experiment with the combination of a state-of-theart sequence structured model, bi-attentive classification network (BCN, <REF>), with our model: BCN+WG, BCN+LVG and BCN+LVeG.',
#  '<REF> combined bi-attentive classification network ) with a pretrained language model with character convolutions on a large-scale corpus (ELMo) and reported an accuracy of 54.7 on sentence-level SST-5.',
#  'Punctuations are ignored as in previous work <REF>.',
#  'In the Gendered Pronoun Resolution challenge which is based on GAP dataset, we designed a unique augmentation strategy for token-level contextual embedding models and applied it to feature based BERT <REF> approach for a 7th place finish.',
#  'The first group are among the models that are submitted to SQuAD v1.1 Leaderboard, specifically DrQA  and BERT <REF> (current state of the art).',
#  'Since sentences evoking the same frame should receive the same labels, we used a verb clustering approach and experimented with a number of pre-trained word and sentence embeddings models, namely Word2Vec <REF>, ELMo , Universal Sentence Embeddings , and fastText .',
#  'We used the ELMo contextualized embedding model by <REF> that generates vectors of a whole context.',
#  'The next generation of approaches includes neural networks that have shown to outperform bag-ofwords models in text classification tasks <REF>.',
#  'In contrast, ELMo <REF> is a recent embedding approach based on bidirectional LSTM networks that considers the context a word occurs in and is thereby able to address certain linguistic peculiarities, e.g., that the same word can have different meanings depending on its context.',
#  'We use GloVe embeddings <REF> for our English models and zzgiga embeddings  for the Chinese models, for a more homogeneous comparison against other parsers .',
#  "An array of existing datasets are available, which test a system's ability to extract factual answers text <REF>, as well as datasets that emphasize simple, commonsense inference (e.g., entailment between sentences) .",
#  'We implement the Reinforced Mnemonic Reader (RMR) <REF>) as our base model, which contains the standard attention mechanism and the two-step answer prediction described in Section 2.1.',
#  'To this end, we compare two state-of-the-art pretrained models, ELMo <REF> and BERT  using both and across seven diverse tasks including named entity recognition, natural language inference (NLI), and paraphrase detection.',
#  'To this end, we compare two state-of-the-art pretrained models, ELMo <REF> and BERT  using both and across seven diverse tasks including named entity recognition, natural language inference (NLI), and paraphrase detection.',
#  'For all tasks, all layers of pretrained representations were weighted together with learned scalar parameters following <REF>.',
#  "For the contextual matching model's similarity function S, we adopt the forward language model of ELMo <REF> to encode tokens to corresponding hidden states in the sequence, resulting in a three-layer representation each of dimension 512.",
#  'Language Model Pretraining Inspired from the computer vision field, where ImageNet <REF>) is used to pretrain models for other tasks , many recent attempts in the NLP community are successful on using language modeling as a pretraining step to extract  feature representations , and to fine-tune NLP models .',
#  'Overview of BERT: BERT <REF> is a deep language model capable of extracting discriminative embeddings.',
#  'Unsupervised transfer learning methods such as ELMo have shown great success for a variety of tasks <REF>.',
#  'Unsupervised transfer learning Embeddings such as GloVe and FastText have become an integral part of the modern NLP pipeline <REF>.',
#  'Convex Combination: This technique is similar to one used by ELMo <REF>.',
#  'We use the stacked alternating LSTM architechture for SRL as per <REF>.',
#  'Several state of the art results in multiple NLP tasks were obtained recently by relying on pretrained language models <REF>.',
#  'In the past, there have been several successful attempts to create "task specific" word embeddings and classifiers <REF>.',
#  'As in, ELMo <REF>, the representation for w i here is a linear combination of the hidden states h j i for each layer j in an LSTM LM, though we depart from the original paper by using only a forward LM.',
#  'The unanswerable classifier is a pairwise classification model <REF> which predicts a label indicating whether the given pair of a passage and a question is unanswerable.',
#  'This is inspired partly by the recent success of unsupervised contextual embedding models using bidirectional recurrent neural network language models <REF> where word embeddings, learned as a function of their context, have been successfully transferred to other tasks.',
#  'Inspired partially by the success of ELMo <REF>, we consider, in addition to 1-hot representations of the amino acids, the inclusion of the hidden layers of a pretrained bidirectional LSTM language model as inputs to the encoder described above.',
#  'We approach the problem with a two-part pipeline where we aim to generate a title for each paragraph of a text, as illustrated in <REF>.',
#  'The first is a contextual word representation using ELMo <REF>, and the second one uses GloVe .',
#  'Our definition of a scaffold task almost includes stand-alone methods for estimating word embeddings <REF>.',
#  'The arrival of modern language models like ELMo <REF>, BERT , and GPT , have significantly advanced the state-of-the art in a wide range of NLP problems.',
#  'Retrieval-based approaches to structured prediction appear particularly compelling now with the recent successes in contextualized word embedding <REF>, which should allow for expressive representations of sentences and phrases, which in turn allow for better retrieval of neighbors for structured prediction.',
#  'Our experiments build upon recent success in self-supervised pre-training <REF> and multi-task fine-tune BERT  to perform the tasks from the GLUE natural language understanding benchmark .',
#  'Works such as Semi-supervised Sequence Learning <REF>, context2vec , Contextualized Word Vectors (CoVe) , and Deep Contextualized Word Representations (ELMo)  seek to remedy this by computing embeddings of words in a sequence using a pretrained recurrent neural language model.',
#  'We conduct experiments on six language datasets including IMDb, Yelp-2, Yelp-5, Amazon-2, Amazon-5 and DBPedia <REF> Experiment settings.',
#  'Collobert and Weston <REF> demonstrated that word embeddings learned by language modeling can improve the performance significantly on semantic role labeling.',
#  'This pretrain-then-transfer learning approach to vision-and-language tasks follows naturally from its widespread use in both computer vision and natural language processing where it has become the de facto standard due to the ease-of-use and strong representational power of large, publicly-available models <REF> trained on large-scale data sources .',
#  'colorizing images <REF> or reconstructing masked words in text ).',
#  'There has been substantial recent interest in both vision <REF> and language around self-supervised representation learning.',
#  'Deep learning methods have produced state-ofthe-art results in many natural language processing (NLP) tasks <REF>.',
#  'To investigate the adaptability of existing discourse relation identification models on dialogue data and our proposed features, we build on the Deep Enhanced Representation (DER) model of <REF> , which demonstrated its efficiency by achieving the current state-of-the-art performance on the PDTB dataset.',
#  'Our method shows improvements over a plain encoder-decoder framework, which reportedly achieves state-of-the-art performance on lemmatization and morphological analysis <REF>.',
#  'For instance, <REF> present a method to fine-tune a pretrained LM for text classification.',
#  '<REF>, is another contextualized word representation.',
#  '<REF> propose a hybrid model, DrQA+PGNet, which combines the sequenceto-sequence model and machine reading comprehension model together to extract and generate answers.',
#  'Sentiment analysis is a well-studied task in the field of natural language processing and information retrieval <REF>.',
#  'Instead of fixed vector embeddings, Cove <REF> uses a machine translation model to embed each word within the context of its sentence.',
#  'Current state-of-the-art approaches employ neural networks which implicitly learn to resolve negation, by either directly training on sentiment annotated data <REF>, or by pre-training the model on a language modeling task .',
#  'Deep, contextualized language models provide powerful, general-purpose linguistic representations that have enabled significant advances among a wide range of natural language processing tasks <REF>.',
#  'In addition to BERT <REF>, we tried to use other models for embeddings generation, namely nnlm , elmo , doc2vec , word2vec  and universal-sentenceencoder .',
#  '<REF> utilized convolutional neural networks (CNNs) for phrase normalization in user reviews, while ,  applied recurrent neural networks (RNNs) to UGTs, achieving similar results.',
#  '(2) a bidirectional layer with attention on top of deep contextualized word representations ELMo <REF>;',
#  'The growing interest in teaching machines to answer questions posed in natural language has led to the introduction of various new datasets for different tasks such as reading comprehension, both extractive, e.g., span-based <REF>, and non-extractive, e.g., multiple-choice questions .',
#  'Current state-of-the-art approaches in machine reading comprehension are grounded on transfer learning and fine-tuning of language models <REF>.',
#  'This success has also motivated a number of iterations on embedding models in a short timespan, from context2vec <REF>, to , ELMo , and BERT .',
#  "In fact, <REF> and  produced contextual embeddings from the SemCor dataset and showed competitive results on 's WSD evaluation framework, with a surprisingly simple approach based on Nearest Neighbors (k-NN).",
#  'ELMo <REF> was the first implementation of contextual embeddings to gain wide adoption, but it was shortly after followed by BERT  which achieved new state-of-art results on 11 NLP tasks.',
#  "The first noteworthy result we obtained was that simply replicating <REF>'s method for WSD using BERT instead of ELMo, we were able to significantly, and consistently, surpass the performance of all previous works.",
#  'Pre-trained contextualized embeddings such as ELMo <REF>, GPTs  and BERT  give improvements on a range of natural language processing tasks by offering rich language model information.',
#  'Word2Vec <REF>, GloVe , fastText , etc), or 3) external sentence embedding resource (i.e.',
#  'Most participating systems did not use any token-level features other than word embeddings, character-level embeddings, or language model embeddings <REF>.',
#  'Traditional word embeddings, like Word2Vec and GloVe, merge different meanings of a word in a single vector representation <REF>.',
#  'In this work, we perform an extensive comparison of existing static and dynamic embeddingbased meaning representation methods on the usage similarity (Usim) task, which involves estimating the semantic proximity of word instances in different contexts <REF>.',
#  'Due to its high reliance on context, Usim can be viewed as a semantic textual similarity (STS) <REF> task with a focus on a specific word instance.',
#  'ELMo (Embeddings from Language Models) representations are contextualized word embeddings derived from the internal states of an LSTM bidirectional language model (biLM) <REF>.',
#  'Context prediction is also a popular representation learning approach in natural language processing, with wellknown examples such as word2vec <REF>, ELMo  and BERT .',
#  'In this work, the parameters of WordCaps are trained with the whole model, while sophisticated pretrained models such as ELMo <REF> or BERT  may also be integrated.',
#  'The NLP community is revisiting the role of linguistic structure in applications with the advent of contextual word representations (CWRs) derived from pretraining language models on large corpora <REF>.',
#  'Fol-lowing <REF>, we use a joint objective maximizing data likelihood objectives in both directions, with shared softmax parameters.',
#  'For training, mSynC i is used to compute the probability of the next word, using a sampled softmax <REF>.',
#  'Learned features For our type-level learned features, we use the 42B uncased GloVe embeddings for the root of the annotated predicate or argument <REF>.',
#  '<REF> paved the way for fast developments on so-called encoder-decoder architectures.',
#  'Variants of the Transformer have achieved state-of-the-art performance in many tasks including language modeling <REF> and machine translation .',
#  'e w k is pre-trained word embedding (word2vec) <REF>.',
#  'Most frequently used word embeddings are word2vec <REF> and GloVe (Global Vectors for Word Representation) .',
#  'Even more interestingly, it has been shown that word embeddings and language models trained on a large generic corpus and then optimized for downstream NLP tasks produce even better results than training the entire model only to solve this one task <REF>.',
#  'We explore four recent models: ELMo, a language model by <REF>, BERT, a transformer by , USE (Universal Sentence Encoder) a sentence encoder by , and T-XL (Transformer-XL) a transformer that includes a recurrence mechanism by .',
#  'Nowadays, as in the majority of other NLP tasks, the state of the art is sequence labelling with Recurrent Neural Networks <REF>.',
#  'In contrast, most previous approaches focused on limited forms of linguistic context, for example by only providing SVO triples such as <REF> to the model .',
#  'To further encode contextual information, we also concatenate ELMo (Embeddings from Language Models) vectors e i from <REF>.',
#  'Embedding from Language Model (ELMo) <REF> is one such method that provides deep contextual embeddings.',
#  '<REF>, it is always beneficial to combine ELMo word representations with standard global word representations like Glove and Word2Vec.',
#  'In various NLP tasks, ELMo outperformed state of the art by significant margin <REF>.',
#  'In various NLP tasks, ELMo outperformed state of the art by significant margin <REF>.',
#  'A more recent work considers iterative estimation using a neural network, called the mutual information neural estimation (MINE) <REF>.',
#  'To evaluate the convergence rate, we plotted the mutual information estimates (18) with uniform reference <REF> against the number of training steps and compared the curve to that of MINE.',
#  'Many recent advances in NLP have been driven by new approaches to representation learningi.e., the design of models whose primary aim is to yield representations of words or sentences that are useful for a range of downstream applications <REF>.',
#  'We use the pretrained character-level convolutional neural network (CNN) from ELMo <REF>) that replaces word embeddings (see  or  for similar usages of the CNN layer).',
#  'We train a left-to-right word-level language model on BWB, which was successfully used by <REF> for pretraining sentence encoders.',
#  'We train a left-to-right word-level language model on BWB, which was successfully used by <REF> for pretraining sentence encoders.',
#  'Previous work has compared the performance of different language models for brain encoding tasks showing that contextual models like long short-term memory networks perform better than standard word-based representations <REF>.',
#  'In particular, BERT pre-trains deep bidirectional representations by jointly conditioning on both left and right contexts in a Transformer <REF>.',
#  'Embedding layer: We embed each word from the sentence and the context with a contextualized word representation using character-based word representations (ELMo) <REF>.',
#  'Embeddings: To compare our model with prior work we experiment with pretrained GloVe (100d) embeddings <REF>.',
#  'A brittle bag-of-words style of query representation faces such challenges as vocabulary mismatch and ambiguity <REF>.',
#  'The Universal Sentence Encoder learns a universally effective encoder using multi-task learning on many language modeling tasks <REF>.',
#  'As the book is too small to train any models, we leverage recent advances in large-scale language model-based representations <REF> to compute a representation of each city.',
#  'We experiment with three different pretrained representations: ELMo <REF>, BERT , and GloVe .',
#  'This approach has been rapidly become popular with works by <REF>, ,  and .',
#  'Finally, the increasingly popular contextualized embedding algorithms, e.g., BERT <REF> or ELMo , are also probabilistic in nature and should thus be affected by stability problems.',
#  'Our deep learning models are based on recurrent neural networks <REF>.',
#  '<REF> proposed CoVe, an approach for contextualized word embeddings directly from machine translation models.',
#  'Finally, we compare our results with other top models in <REF>.',
#  'Neural networks are bringing incredible performance gains on text classification tasks <REF>.',
#  'At the word level, pre-trained word embeddings <REF> encode each word into a continuous vector representation, have been widely used in many applications .',
#  'Besides, we combine our MTL-based sentence encoders with another existing sentence encoder <REF> trained with different learning signals, and contextualized word vectors , to build a more robust and transferable sentence encoder.',
#  'To this end, <REF> proposed to train a universal sentence encoder in the form of a bidirectional LSTM using the supervised natural language inference data, outperforming unsupervised approaches like SkipThought.',
#  'Existing studies <REF> leverage large amount of data to train sentence or word representations.',
#  'Existing studies <REF> leverage large amount of data to train sentence or word representations.',
#  'Our best multi-task model makes use of ELMo <REF>, a recently proposed pre-training technique.',
#  'Beyond multi-task learning, much work in developing general NLU systems has focused on sentence-to-vector encoders <REF>, leveraging unlabeled data , labeled data , and combinations of these .',
#  'Pre-trained embeddings such as word embeddings <REF> and sentence embeddings  have become fundamental NLP tools.',
#  'Skip-thought <REF> proposed a approach for unsupervised learning of a generic, distributed sentence encoder.',
#  'Recently, deep learning models have been proposed to learn powerful input representations for text classification <REF> as well as the XMC problem .',
#  'XML-CNN <REF> employed CNN models on the text input, while AttentionXML  and HAXMLNet  used attention models to extract the embeddings from text inputs.',
#  'In this work, we use one of the state-of-the-art word representations, ELMo <REF>, to represent the words in the label.',
#  'Bidirectional Encoder Representations from Transformers (a.k.a BERT <REF>) stands as the latest developments in this direction that significantly outperforms many predecessors such as the Generative Pretrained Transformer (GPT)  and Embeddings from Language Models (ELMo) .',
#  'External Transferable Knowledge and Learning schemas Clearly, the improvement in accuracy and performance is not merely because of the shift from feature engineering to structure engineering, but the flexible ways to incorporate external knowledge <REF> and learning schemas to introduce extra instructive constraints .',
#  'The success of neural network-based models on NLP tasks cannot only be attributed to the shift from feature engineering to structural engineering, but the flexible ways to incorporate external knowledge <REF>.',
#  'Unsupervised transferable knowledge Two typical unsupervised transferable knowledge are explored in this paper: context independent word embeddings <REF> and contextualized word embeddings , have put the state-of-the-art results to new level on a large number of NLP taks recently.',
#  'State-of-the-art neural machine translation (NMT) models generally implement encoder and decoder as multiple layers <REF>, in which only the top layer is exploited in the subsequent processes.',
#  'While studies have shown deeper layers extract more semantic and more global features <REF>), these do not prove that the last layer is the ultimate representation for any task.',
#  'A capsule is a group of neurons whose outputs represent different properties of the same entity from the input <REF>.',
#  'Concerning natural language processing, <REF> have found that combining different layers is helpful and their model significantly improves state-of-the-art models on various tasks.',
#  '<REF> applied a CNN-CRF model and gained competitive results to the best statistical models.',
#  'Multee uses ESIM <REF>), a recent sentence-level entailment model, pre-trained on SNLI and MultiNLI datasets.',
#  'We used PyTorch <REF> and AllenNLP to implement our models and ran them on Beaker 7 .',
#  'An example model structure using ELMo embeddings <REF> is illustrated in .',
#  'Contextual word embeddings We consider contextual word embeddings generated from ELMo <REF> using the allennlp package .',
#  'Subword vector representations are now a standard part of neural architectures for natural language processing (e.g., <REF>.',
#  'Word embedding, also known as word representation, represents a word as a vector capturing both syntactic and semantic information, so that the words with similar meanings should have similar vectors <REF>.',
#  'Word embedding, also known as word representation, represents a word as a vector capturing both syntactic and semantic information, so that the words with similar meanings should have similar vectors <REF>.',
#  '• ELMO <REF>: a model generates embeddings for a word based on the context it appears.',
#  '<REF> We release the codes in https://github.com/ microsoft/MASS.',
#  'Feature-based approaches mainly leverage pretraining to provide language representations and features to the downstream tasks, which includes word-level representations <REF> and sentence-level representations , as well as context sensitive features from the NMT model  and ELMo .',
#  '• Standard language modeling has long been used for pre-training, and the most prominent ones are the recently proposed ELMo <REF> and OpenAI GPT .',
#  'The pretrained English ELMo model is from <REF>, and the Chinese one is from , which is hosted at .',
#  'Recently, there is a growing interest in applying MTL to representation learning using deep neural networks (DNNs) <REF> for two reasons.',
#  'For visual-content understanding, people have developed several backbone models <REF> and shown their effectiveness on large vision datasets .',
#  'Pretrained word vectors <REF> have become standard components of most architectures.',
#  'Word2vec <REF>, which extracts knowledge from unannotated texts, has been one of the major advancements in natural language processing.',
#  'Training on specific NLP tasks (e.g., language modeling <REF>) where word representations were byproducts of the NLP tasks, or direct optimization of word representations based on various hypotheses  was conducted to obtain word representations.',
#  'The experimental results are presented in <REF>.',
#  'Chieu and Ng <REF> 88.31  88.76 Ando and  89.31  89.59  90.',
#  'Chieu and Ng <REF> 88.31  88.76 Ando and  89.31  89.59  90.',
#  'We chose to employ the state-of-the-art RTE model proposed by <REF> which is a re-implementation of the widely used decomposable attention model developed by .',
#  'In addition to human action recognition, our work relates to other multimodal tasks such as visual question answering <REF>, video summarization , and mapping text descriptions to video content .',
#  'This is not surprising given that ELMo uses two bidirectional LSTMs and has improved the state-of-the-art in many NLP tasks <REF>.',
#  'The idea here has similar motivation with the bidirectional language model <REF>, with the exception that the bidirectional language model is proposed for word understanding or downstream NLP tasks, which are not well-suited for the generating task.',
#  'The first approach is based on the recently proposed contextualized embeddings from language models, ELMo <REF>.',
#  'Aligning monolingual word vector spaces using a seed dictionary was originally proposed in <REF>.',
#  'ELMo (Embeddings from Language Models) is a recently-proposed deep model for obtaining contextualized word embeddings, which are calculated as the hidden states of a bi-LSTM network trained as a language model <REF>.',
#  'Recent works on learnable evaluation metrics use simple word embeddings such as word2vec and GLoVe as input to their models <REF>.',
#  "Unlike previous static word embeddings like word2vec 2 , which maps words to constant embeddings, contextualized embeddings such as ELMo, OpenAI GPT and BERT consider word embeddings as a function of the word's context in which the word is appeared <REF>.",
#  "Unlike previous static word embeddings like word2vec 2 , which maps words to constant embeddings, contextualized embeddings such as ELMo, OpenAI GPT and BERT consider word embeddings as a function of the word's context in which the word is appeared <REF>.",
# ...
#  'Model Architecture -our model has an embedding layer of 300 dimensions using fasttext embedding, and 1024 dimensions using ELMo <REF> embedding.',
#  'Until recently, the dominant paradigm in approaching natural language processing (NLP) tasks has been to concentrate on neural architecture design, using only task-specific data and word embeddings such as GloVe <REF>.',
#  'A shift in trend towards more neural based approaches can be traced back to <REF> proposed an effective deep neural model with a CRF layer on top, that requires almost no feature engineering and learns important features from word embeddings trained on large corpora.',
#  'Word Representations To represent words from samples, we used deep contextualized word representations <REF> also known as ELMo along with its available pre-trained model 1 .',
#  'Many state-of-the-art RE models rely upon domain-specific external syntactic tools to construct dependency paths between the entities in a sentence <REF>.',
#  'The input for each token is a concatenation of the character reprensetation, GLoVe <REF> word embeddings, and ELMo embeddings .',
#  'where we further concat the output of the contextual Bi-LSTM network with the pre-trained char embeddings for its good performance <REF>.',
#  '<REF> 40.0 / 51.0 40.4 / 51.0 Match-LSTM  64.1 / 73.9 64.7 / 73.7 DrQA  -/ -70.7 / 79.4 DCN+  74.5 / 83.1 75.1 / 83.1 Interactive AoA Reader+  -/ -75.8 / 83.8 FusionNet  -/ -76.0 / 83.9 SAN  76.2 / 84.0 76.8 / 84.4 AttentionReader+ (unpublished) -/ -77.3 / 84.9 BiDAF + Self Attention + ELMo  -/ -78.6 / 85.8 r-net+  -/ -79.9 / 86.5 SLQA+ 80.0 / 87.0 80.4 / 87.0 Ensemble model  -/ -78.8 / 85.9 DCN+  -/ -78.9 / 86.0 Interactive AoA Reader+  -/ -79.0 / 86.4 SAN  78 TriviaQA is a newly available machine comprehension dataset consisting of over 650K contextquery-answer triples.',
#  'Following <REF>), we model SRL as a span tagging problem using BIO encoding 2 and use an 8-layer deep BiLSTM with forward and backward directions interleaved.',
#  '<REF> following .',
#  '<REF> shows the hyper-parameters of our models.',
#  'To represent complex characteristics of words and word usage across different linguistic contexts effectively, a new model for deep contextualized word representation was introduced in <REF>.',
#  'To achieve a strong baseline 3 , we also incorporate ELMOs <REF> to English system for better representations.',
#  'The early Word2Vec <REF> and Glove models  Manning 2014) focused on feature-based approaches to transform words into distributed representations.',
#  'Task-specific output layer Glyce-BERT representations are used to represent the token at that position, similar as word embeddings or Elmo emebddings <REF>.',
#  'Large-scale language models have been shown to dramatically improve the performance of natural language understanding (NLU) systems on a broad range of tasks <REF>.',
#  'Given the demonstrated quality of samples from large language models <REF>, it is natural to expect that encoder-agnostic adaptation should give improvements in coherence and grammatically even when the source modality is not text, such as with image captioning or classconditional generation.',
#  'Transfer learning with language models Extending upon the success of pretrained word embeddings <REF>, contextual word vectors based on LSTMs first demonstrated strong results across discriminative NLU tasks .',
#  'Pretraining-Based Transfer Learning for NLG <REF> use BERT in the encoder and decoder of a summarization model via a unique cloze generative process.',
#  'The Densely Interactive Inference Network <REF> adopts DenseNet , a 2-dimensional convolution architecture, to extract high-order word-by-word interaction between n-gram pairs.',
#  'where <REF> represents the concatenation and u v represents the element-wise multiplication of u and v. We project this final representation h to label space to classify the given sentence pair (see ).',
#  'MRPC QNLI CoLA SST-2 BiLSTM+ELMo (Single-Task) <REF>   Training Details: We use pre-trained ELMo 4 to obtain sentence representations as inputs to our model , and the Gaussian Process implementation is based on Scikit-Optimize 5 , and we adopt most of the default configurations.',
#  'Initially the word embeddings (e.g., <REF> of question tokens Q and context tokens C are taken as input and fed into contextual integration layers, such as LSTMs  or self attentions , to encode the question and context.',
#  ', c m } with pretrained GloVe <REF> and ELMo  embeddings.',
#  'Since 2012, the field of artificial intelligence has reported remarkable progress on a broad range of capabilities including object recognition, game playing, machine translation, and more <REF>.',
#  'Data efficiency has received significant attention over the years <REF>.',
#  'Previous work in machine translation has suggested the utility of using a pretrained LM as a lower layer of the decoder <REF>.',
#  'There exists a cornucopia of DRs for words including word2vec <REF>, GloVe , fastText  and very recently ELMo .',
#  'Recently, DRs has been identified as a promising approach to encode tuples for ER <REF>.',
#  'Lastly, we evaluate our system on the SQuAD 2.0 dataset <REF>, a reading comprehension benchmark augmented with unanswerable questions.',
#  'We use the Reinforced Mnemonic Reader (RMR) <REF>, one of the state-of-the-art reading comprehension models on the SQuAD 1.1 dataset, as our base reader.',
#  'This motivated our proposal to augment the pre-trained branch with additional random units (as illustrated in <REF>).',
#  'Contextualized representation models such as ELMo <REF> and  have recently achieved state-of-the-art results on a diverse array of downstream NLP tasks.',
#  'Pretrained word embeddings <REF> are a staple tool for NLP.',
#  'Recent work has explored many token-level properties of these representations, such as their ability to capture part-of-speech tags <REF>, morphology , or word-sense disambiguation .',
#  'We approach these questions with a probing model ( <REF>) that sees only the contextual embeddings from a fixed, pretrained encoder.',
#  'ELMo <REF>) is a two-layer bidirectional LSTM language model, built over a contextindependent character CNN layer and trained on the Billion Word Benchmark dataset , consisting primarily of newswire text.',
#  'According to several recent studies <REF>, contextual sentence and word embeddings can improve the performance of the state-of-the-art NLP systems by a significant margin.',
#  'Compared to other datasets, EmoContext dataset <REF> has very short conversations consisting only three utterances where the goal is to label the 3rd utterance as shown in .',
#  'Compared to other datasets, EmoContext dataset <REF> has very short conversations consisting only three utterances where the goal is to label the 3rd utterance as shown in .',
#  'For these experiments we use averaged word vectors as a sentence representation for various  types of word vector, with similarity computed by the different correlation coefficients as well as cosine similarity and APSynP <REF>.',
#  'For example, both narratives in <REF> are regarding military conflict.',
#  'The architecture of the real/fake encoder is shown in <REF>.',
#  'Unsupervised representation learning has been highly successful in the domain of natural language processing <REF>.',
#  'AR language modeling seeks to estimate the probability distribution of a text corpus with an autoregressive model <REF>.',
#  'Approaches like ELMo <REF> concatenate forward and backward language models in a shallow manner, which is not sufficient for modeling deep interactions between the two directions.',
#  'To bypass the scarcity of causal instances in relation extraction datasets, we exploit transfer learning, namely ELMO <REF> and   , comparing against a bidirectional GRU with self-attention .',
#  'To bypass the scarcity of causal instances in relation extraction datasets, we exploit transfer learning, namely ELMO <REF> and   , comparing against a bidirectional GRU with self-attention .',
#  'We use cross-entropy loss, the Adam optimizer (Kingma and Ba, 2015), and dropout layers <REF> before and after the BI-GRU ).',
#  'We use cross-entropy loss, the Adam optimizer (Kingma and Ba, 2015), and dropout layers <REF> before and after the BI-GRU ).',
#  'The latter finding is not in line with previously reported results <REF>, where ELMO and BERT were found to improve performance in most NLP tasks without studying, however, the effect of dataset size.',
#  '• We used embedding representations from a language model <REF> at the input to the LSTMs (ELMo in the results).',
#  'There exist some popular word embedding methods to represent the text into vectors, including Word2Vec <REF>, GloVe , ELMo  and BERT .',
#  'To this end, we intent to examine the recently published ELMo embeddings <REF> for German.',
#  'As modern neural networks evolve, dynamic neural network structures such as variable-length sequences <REF>, trees , and graphs  become increasingly important.',
#  'As such, the quality of mention detection affects very deeply both the quality of an annotation and the performance of a model for such applications <REF>.',
#  'Despite neural networks having shown high performance in many natural language processing tasks, the rule-based mention detector of the Stanford deterministic system <REF> remains frequently used in top performing coreference systems , including the best pipeline system itself based on neural networks .',
#  'Despite neural networks having shown high performance in many natural language processing tasks, the rule-based mention detector of the Stanford deterministic system <REF> remains frequently used in top performing coreference systems , including the best pipeline system itself based on neural networks .',
#  'For word embeddings, GloVe <REF> and ELMo  embeddings are used.',
#  'For our first model (LEE MD) we use the default settings of <REF>.',
#  'LMs are used as testbeds for evaluation of generative models of text, and have applications such as rescoring of upstream language generation inputs <REF>, grammatical error correction , or pre-training of sentence representations .',
#  'For a proof of concept, we chose the word2vec embedding <REF> as the word vector space to interpret.',
#  '1 A demonstration on how to easily integrate two recent, more complex, embedding componentsELMo embeddings <REF> and TCN representations -is also made available.',
#  'Pre-training a LM in order to initialize the weights of an encoder has been reported to improve generalization and training stability for sequence classification (Dai and Le, 2015) as well as translation and summarization <REF>.',
#  'We formulate the answer recycling problem as a constrained optimization based on the relevance and entailment scores between each candidate negative answer and the gold answer, as measured by state-of-the-art natural language inference models <REF>.',
#  'Here, we employ state-of-the-art models for Natural Language Inference: BERT <REF> and ESIM+ELMo , respectively.',
#  'a. BERT <REF>: BERT is a recently released NLP model that achieves state-of-the-art performance on many NLP tasks.',
#  'We used ESIM+ELMo for this task <REF>, as it still does quite well on two-sentence natural language inference tasks (although not as well as BERT), and can be made much more efficient.',
#  'In the past years, the development of deep learning methods of language representation was swift, and the newer methods were shown to have significant effects on improving other natural language processing tasks <REF>.',
#  'A new type of deep contextualized word representation was introduced by <REF>.',
#  'Recently, <REF> have shown that a deep contextualized LSTM-based language model (LSTM-LM) is able to capture different language concepts in a layer-wise fashion, e.g., the lowest layer captures language syntax and topmost layer captures semantics.',
#  'An extension of NADE and RSM, DocNADE <REF>) models collections of documents as orderless bags of words (BoW approach), thereby disregarding any language structure.',
#  'BERT <REF> represents the latest refinement in a series of neural models that take advantage of pretraining on a language modeling task .',
#  'Following the work of Radford et al., the model is pretrained on the BooksCorpus dataset <REF> which contains over 7,000 unpublished books (about 800M words) from a variety of genres (Adventure, Fantasy, Romance...).',
#  'We additionally observe that when we use GloVe embeddings <REF> instead of contextual ELMo embeddings , the gap is even higher.',
#  'We utilize the ESIM neural architecture originally used for natural language inference <REF>.',
#  'Neural Semantic Parser We use a standard semantic parser provided by AllenNLP <REF>, based on a sequence-to-sequence model .',
#  '• Statistical model, proposed by <REF>, uses human-designed entity-level  features between clusters and mentions for coreference resolution.',
#  'The first contextual word representation that we consider to overcome this issue is ELMo <REF>.',
#  'Word embeddings are perceived as one of the most impactful contributions from unsupervised representation learning to natural language processing from the past few years <REF>.',
#  'To this end, <REF> and  introduced an evaluation framework for sentence encoders that tests both their performance on downstream tasks as well as their ability to capture linguistic properties.',
#  'To this end, <REF> and  introduced an evaluation framework for sentence encoders that tests both their performance on downstream tasks as well as their ability to capture linguistic properties.',
#  'Neural LMs have also been applied successfully to improve downstream applications <REF>.',
#  'In <REF>, researchers have shown that pre-trained LMs can be used as feature representations for a sentence, or a paragraph to improve NLP applications such as document classification, machine translation, question answering, etc.',
#  '<REF> used bi-directional RNNs to predict the last word of a passage in the LAMBADA challenge.',
#  'ELMo embeddings To further improve performance, we also add ELMo word representations <REF> to the BiLSTM input (in the +ELMo rows).',
#  'The proposed syntatic patterns were performed as a normalized bag of pattern features and first compared with with two traditional baseline method: (1) TF-IDF featured model <REF>: uses 1 and 2 grams features, where a document represents a user; and (2) LIWC featured model : 64 categories were selected from the LIWC affect lexicon, including syntactic features, topical features (e.g., work and friends), and psychological features (e.g., emotions and social context).',
#  'The pretrained neural language models are proved effective in the sequence labelling models <REF>- .',
#  'More recently, language modeling has been shown to give a sensible loss function for learning high-quality unsupervised representations in tasks like text classification <REF>, sentiment detection  or word vector learning  and there is thus a revived interest in developing better language models.',
#  'Historically, the first semantic representations that were used were handcrafted attributes <REF>.',
#  'Natural language inference is also a well studied area of research, particularly on the MultiNLI <REF> and SNLI  datasets.',
#  'Unsupervised: It is well known that unsupervised pre-training using language-modeling objectives <REF>, can improve performance on many tasks.',
#  'Representation learning techniques at the word level, such as word embedding <REF> and contextualized representations , have demonstrated their effectiveness in NER.',
#  'Typically, in traditional methods, handcrafted features are leveraged to capture textual signals, and conditional random fields (CRF) are employed to model label dependencies <REF>.',
#  'By leveraging pre-trained machine translation models, CoVe constructs contextualized word representations <REF>.']

# %%
import pandas as pd
df = pd.DataFrame(x, columns=["paragraph"])
df.to_csv('Elmo-605.csv', index=False)
